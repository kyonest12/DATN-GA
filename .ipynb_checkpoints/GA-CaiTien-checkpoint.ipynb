# %%
import math
def quicksort(arr, compare):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if compare(x, pivot) == 1]
    middle = [x for x in arr if compare(x, pivot) == 2]
    right = [x for x in arr if compare(x, pivot) == 0]
    return quicksort(left, compare) + middle + quicksort(right, compare)

# %%
def inP(c):
    for i in range(len(c.processors)):
        print("(", c.processors[i].typed, c.processors[i].idd, ")", end = " ")
    print()

# %%
network = 20*1024*1024

class processor:
    def __init__(self, cu, cost):
        self.cu = cu
        self.cost = cost

numberOfProcessors = 9
listProcessors = [
    processor(1, 0.12),
    processor(1.5, 0.195),
    processor(2, 0.28),
    processor(2.5, 0.375),
    processor(3, 0.48),
    processor(3.5, 0.595),
    processor(4, 0.72),
    processor(4.5, 0.855),
    processor(5, 1)
]

class VM:
    def __init__(self, typed, idd):
        self.typed = typed
        self.idd = idd

# %%
import random
import numpy as np

# %%
import xml.etree.ElementTree as ET
import numpy as np
import re

def extractNumberFromString(string):
    numbers = re.findall(r'\d+', string)
    if numbers:
        return int(numbers[0])  

class task:
    def __init__(self, sources, destinations, dataSize):
        self.sources = sources
        self.destinations = destinations
        self.dataSize = dataSize

class workFlow:
    def __init__(self, filePath, deadline):
        self.numberOfTasks = extractNumberFromString(filePath)
        self.tasks = [task([], [], 0)] * self.numberOfTasks
        self.DAG = self.getDAGFromXml(filePath)
        self.deadline = deadline
        degree = self.getDegree()
        self.inDegree = degree[0]
        self.zeroInDegree = degree[1]
        self.subDeadline = [-1] * self.numberOfTasks
        self.rank = [-1] * self.numberOfTasks
        self.calSubDeadline()
       
    def getDAGFromXml(self, filePath):
        tree = ET.parse(filePath)
        root = tree.getroot()

        # dx là 1 dict như sau: dx[name][0] là mảng chứa id của các jobs nhận dữ liệu đầu vào có tên là name
        ######################: dx[name][1] là giá trị id của job xuất ra dữ liệu có tên là name
        dx = {}
        namespace = {'dax': 'http://pegasus.isi.edu/schema/DAX'}

        DAG = [[0 for _ in range(self.numberOfTasks)] for _ in range(self.numberOfTasks)]
        jobs = {}
        inData = [[]] * self.numberOfTasks
        outData = [[]] * self.numberOfTasks

        tasks = []
        for i in range(self.numberOfTasks):
            tasks.append(task([], [], 0))
        self.numberOfTasks = 0
        for job in root.findall('.//dax:job', namespace):
            job_id = extractNumberFromString(job.attrib['id'])
            self.numberOfTasks = max(self.numberOfTasks, job_id)
            uses = job.findall('.uses', namespace)
            inputs = []
            outputs = []
            dataSize = 0

            for use in job.findall('.//dax:uses', namespace):
                file = use.attrib['file']
                link = use.attrib['link']
                data = int(use.attrib['size'])
                if data < 0:
                    data = 0 - data
                if file not in dx:
                    dx[file] = [[], -1, data]
                if link == 'input':
                    dx[file][0].append(job_id)
                elif link == 'output':
                    dx[file][1] = job_id

            #inData[job_id] = inputs
            #outData[job_id] = outputs

            #!__________________________________________________
            tasks[job_id].dataSize = float(job.attrib['runtime'])
        self.numberOfTasks += 1
        for dependencies in root.findall('.//dax:child', namespace):
            childId = extractNumberFromString(dependencies.attrib['ref'])
            for parents in dependencies.findall('.//dax:parent', namespace):
                parentId = extractNumberFromString(parents.attrib['ref'])
                tasks[childId].sources.append(parentId)
                tasks[parentId].destinations.append(childId)

        for key in dx:
            for i in range(len(dx[key][0])):
                if dx[key][1] == -1:
                    continue
                DAG[dx[key][1]][dx[key][0][i]] = dx[key][2] / network
        for i in range(self.numberOfTasks):
            self.tasks[i] = tasks[i]
        return DAG

    def calRank(self, task):
        self.rank[task] =  self.tasks[task].dataSize / listProcessors[8].cu 
        maxx = 0
        for j in range(len(self.tasks[task].destinations)):
            child = self.tasks[task].destinations[j]
            if self.rank[child] == -1:
                self.calRank(child)
            maxx = max(maxx, self.rank[child] + self.DAG[task][child] / network)
        self.rank[task] += maxx
        
    def calSubDeadline(self):
        outDegree = [0] * self.numberOfTasks
        for i in range(0, self.numberOfTasks):
            outDegree[i] += len(self.tasks[i].destinations)
        zeroOutDegree = []
        for i in range(0, self.numberOfTasks):
            if outDegree[i] == 0:
                zeroOutDegree.append(i)     
                
        inDegree_copy = self.inDegree[:]
        zeroInDegree_copy = self.zeroInDegree[:]
        maxSpeed = listProcessors[8].cu
        
        while(len(zeroOutDegree) > 0):
            task = zeroOutDegree[0]
            zeroOutDegree.pop(0)
            if self.rank[task] == -1:
                self.calRank(task)
            for j in range(len(self.tasks[task].sources)):
                adj = self.tasks[task].sources[j]
                outDegree[adj] -= 1
                if outDegree[adj] == 0:
                    zeroOutDegree.append(adj)
        
        rankEntry = 0
        for i in range(len(self.zeroInDegree)):
            tt = self.zeroInDegree[i]
            rankEntry = max(rankEntry, self.rank[tt])
        for i in range(self.numberOfTasks):
            self.subDeadline[i] = (self.deadline / rankEntry) * (rankEntry - self.rank[i] + (self.tasks[i].dataSize / maxSpeed))
        
    def getDegree(self):
        inDegree = [0] * self.numberOfTasks
        zeroInDegree = []
        for i in range(0, self.numberOfTasks):
            inDegree[i] += len(self.tasks[i].sources)
        for i in range(0, self.numberOfTasks):
            if inDegree[i] == 0:
                zeroInDegree.append(i)
        return (inDegree, zeroInDegree)

# %%
def isBetter(a, b):
    
    if a.completionTime == b.completionTime and a.cost == b.cost:
        return 2
    if a.completionTime <= workflow.deadline and b.completionTime <= workflow.deadline:
        return a.cost < b.cost
    if a.completionTime <= workflow.deadline and b.completionTime > workflow.deadline:
        return 1
    if a.completionTime > workflow.deadline and b.completionTime > workflow.deadline:
        return a.completionTime < b.completionTime
    if a.completionTime > workflow.deadline and b.completionTime <= workflow.deadline:
        return 0

# %%
import math

def diff(a, b):
    return not ((a.typed == b.typed) and (a.idd == b.idd))

class Chromosome:
    def __init__(self, processors, tasks):
        self.processors = processors
        self.tasks = tasks
        self.completionTime = 0
        self.FTofTasks = [0.0] * numberOfTasks
        self.cost = 0.0
        self.isHillClimbing = False
        #self.cal_fitness()

    @staticmethod
    def crossover(chromosome1, chromosome2, crossover_rate):

        numTasks = len(chromosome1.tasks)
        Child1 = Chromosome([VM(0, 0)] * numTasks, [-1] * numTasks)
        Child2 = Chromosome([VM(0, 0)] * numTasks, [-1] * numTasks)

        if random.random() > crossover_rate:
            return None

        t = random.randint(0, 1)
        if 1:
            #get position to crossover
            pos = random.randint(1, numTasks)
            dxC1 = [False] * (numTasks + 1)
            dxC2 = [False] * (numTasks + 1)
            #take left part from parents
            for i in range(pos):
                Child1.tasks[i] = copy.deepcopy(chromosome1.tasks[i])
                Child1.processors[i] = copy.deepcopy(chromosome1.processors[i])
                dxC1[chromosome1.tasks[i]] = True
                Child2.tasks[i] = copy.deepcopy(chromosome2.tasks[i])
                Child2.processors[i] = copy.deepcopy(chromosome2.processors[i])
                dxC2[chromosome2.tasks[i]] = True

            #take right part from parents
            ps = pos
            for i in range(numTasks):
                if dxC1[chromosome2.tasks[i]] == False:
                    Child1.processors[ps] = copy.deepcopy(chromosome2.processors[i])
                    Child1.tasks[ps] = copy.deepcopy(chromosome2.tasks[i])
                    dxC1[chromosome2.tasks[i]] = True
                    ps += 1
            ps = pos
            for i in range(numTasks):
                if dxC2[chromosome1.tasks[i]] == False:
                    Child2.processors[ps] = copy.deepcopy(chromosome1.processors[i])
                    Child2.tasks[ps] = copy.deepcopy(chromosome1.tasks[i])
                    dxC2[chromosome1.tasks[i]] = True
                    ps += 1

            return Child1, Child2
        '''else:
            crossover_point = random.randint(1, len(chromosome1.processors) - 1)
            
            head1 = copy.deepcopy(chromosome1.processors[:crossover_point])
            tail1 = copy.deepcopy(chromosome1.processors[crossover_point:])
            head2 = copy.deepcopy(chromosome2.processors[:crossover_point])
            tail2 = copy.deepcopy(chromosome2.processors[crossover_point:])
            
            # Tạo hai con mới
            Child1.processors = head1 + tail2
            Child2.processors = head2 + tail1
            
            Child1.tasks = copy.deepcopy(chromosome1.tasks)
            Child2.tasks = copy.deepcopy(chromosome2.tasks)
            
            return Child1, Child2'''

    def mutate(self, mutation_rate):
        rand = random.random()
        if rand < mutation_rate:
            mutated_processors = self.processors[:]  # Create a copy of distributing

            mutate_position = random.randint(0, len(mutated_processors) - 1)
            mutated_processors[mutate_position] = VM(random.randint(0, numberOfProcessors - 1), random.randint(0, numberOfTasks - 1))
            return Chromosome(mutated_processors, self.tasks)
        return self

    def self_improve(self):
        dx = {}
        mutated_processors = self.processors[:]  # Create a copy of distributing

        pool = []
        for i in range(len(self.processors)):
            typed = self.processors[i].typed
            idd = self.processors[i].idd
            if (typed, idd) not in dx:
                dx[(typed, idd)] = True
                pool.append((typed, idd))

        mutate_position = random.randint(0, len(mutated_processors) - 1)
        pos = random.randint(0, len(pool) - 1)
        mutated_processors[mutate_position] = VM(pool[pos][0], pool[pos][1])
        return Chromosome(mutated_processors, self.tasks)

    def cal_fitness(self):
        FTofTasks = [0] * numberOfTasks
        processor = [0] * numberOfTasks
        FT = np.zeros((numberOfProcessors, numberOfTasks))
        endLeaseTime = np.zeros((numberOfProcessors, numberOfTasks))
        startLeaseTime = array = np.full((numberOfProcessors, numberOfTasks), 1e9)
        dx = {}
        pool = []
        completionTime = 0.0
        cost = 0.0
        for i in range(len(self.tasks)):
            processor[self.tasks[i]] = self.processors[i]

        for i in range(len(self.tasks)):
            task = self.tasks[i]
            prc = self.processors[i].typed
            idd = self.processors[i].idd

            if ((prc, idd) not in dx):
                pool.append((prc, idd))
                dx[(prc, idd)] = True


            DAT_processor = FT[prc][idd]
            maxcost = 0.0
            for j in range(len(workflow.tasks[task].sources)):
                parent = workflow.tasks[task].sources[j]
                costTt = FTofTasks[parent] + ((DAG[parent][task]) if diff(processor[task], processor[parent]) else 0.0)
                DAT_processor = max(DAT_processor, costTt)
                maxcost = max(maxcost, costTt)
            FTofTasks[task] = DAT_processor + computationTime[task][prc]
            FT[prc][idd] = FTofTasks[task]
            self.FTofTasks[task] = FTofTasks[task]
            completionTime = max(completionTime, FTofTasks[task])

            endLeaseTime[prc][idd] = max(endLeaseTime[prc][idd], FTofTasks[task])
            for j in range(len(workflow.tasks[task].destinations)):
                child = workflow.tasks[task].destinations[j]
                costTt = FTofTasks[task] + ((DAG[task][child]) if diff(processor[task], processor[child]) else 0.0)
                endLeaseTime[prc][idd] = max(endLeaseTime[prc][idd], costTt)
                FT[prc][idd] = max(FT[prc][idd], costTt)

            startLeaseTime[prc][idd] = min(startLeaseTime[prc][idd], DAT_processor - maxcost)

        for i in range(len(pool)):
            cost += (math.ceil((endLeaseTime[pool[i][0]][pool[i][1]] - startLeaseTime[pool[i][0]][pool[i][1]]) / 3600)) * listProcessors[pool[i][0]].cost

        self.cost = cost
        self.completionTime = completionTime

# %%
import copy
import numpy as np

def improveHeuristic(chromosome):
    cTest = copy.deepcopy(chromosome)
    poolVm = []
    dx = [[False for _ in range(numberOfTasks)] for _ in range(numberOfProcessors)]      
    taskOfVm = np.empty((numberOfProcessors, numberOfTasks), dtype=object)
    for i in range(numberOfProcessors):
        for j in range(numberOfTasks):
            taskOfVm[i, j] = []

    for i in range(len(chromosome.processors)):
        Vm = chromosome.processors[i]
        if dx[Vm.typed][Vm.idd] == False:
            poolVm.append(Vm)
            dx[Vm.typed][Vm.idd] = True
        taskOfVm[Vm.typed][Vm.idd].append(i)
    
    for i in range(len(poolVm)):
        vm = poolVm[i]
        
    for i in range(len(poolVm)):
        vm1 = poolVm[i]
        tt = vm1.typed + 1
        xuly = []
        for j in range(len(taskOfVm[vm1.typed][vm1.idd])):
            xuly.append(taskOfVm[vm1.typed][vm1.idd][j])

        lastTask = chromosome.tasks[xuly[len(xuly) - 1]]
        while (chromosome.FTofTasks[lastTask] > workflow.subDeadline[lastTask] and tt < numberOfProcessors):
            '''if tt == vm1.typed:
                tt += 1
                continue'''
            for j in range(len(xuly)):
                taskt = xuly[j]
                chromosome.processors[taskt].typed = tt
            chromosome.cal_fitness()
            if isBetter(chromosome, cTest) == 1:
                cTest = chromosome
            tt += 1
    return cTest

# %%
def tournamentSelection(tournament):
    winner = Chromosome([], [])
    winner.completionTime = 1e8
    winner.cost = 1e8
    for i in range(len(tournament)):
        if isBetter(tournament[i], winner) == 1:
            winner = tournament[i]
    return winner

# %%
def chooseProcessor(task):
    return random.randint(0, numberOfProcessors - 1)

def createRandomChromosome(inDegree, zeroInDegree, typedd):
    inDegree_copy = inDegree[:]
    zeroInDegree_copy = zeroInDegree[:]
    maxNumOfVm = [0] * numberOfProcessors

    chromosome = Chromosome([0] * numberOfTasks, [0] * numberOfTasks)
    i = 0
    while(len(zeroInDegree_copy) > 0):
        index_task = random.randint(0, len(zeroInDegree_copy) - 1)
        task = zeroInDegree_copy[index_task]
        processor = chooseProcessor(task)
        chromosome.tasks[i] = task
        chromosome.processors[i] = VM(processor, 0)
        maxNumOfVm[processor] += 1
        zeroInDegree_copy.pop(index_task)
        for j in range(len(workflow.tasks[task].destinations)):
            adj = workflow.tasks[task].destinations[j]
            inDegree_copy[adj] -= 1
            if inDegree_copy[adj] == 0:
                zeroInDegree_copy.append(adj)
        i += 1
    if typedd == 1:
        for i in range(len(chromosome.tasks)):
            chromosome.processors[i].idd = random.randint(0, maxNumOfVm[chromosome.processors[i].typed] - 1)
    #multi thread
    chromosome.cal_fitness()
    return chromosome

def generateRandomPopulation(size, percentage, inDegree, zeroInDegree):
    randomPopulation = []

    size = math.ceil(size * percentage)
    randomType = 0
    for i in range(int(size * 0.75)):
        randomPopulation.append(createRandomChromosome(inDegree, zeroInDegree, 1))
    for i in range(int(size * 0.25)):
        randomPopulation.append(createRandomChromosome(inDegree, zeroInDegree, 0))
    return randomPopulation

# %%
def diff(a, b):
    return not ((a.typed == b.typed) and (a.idd == b.idd))

def createHeuristicChromosome(inDegree, zeroInDegree):
    inDegree_copy = inDegree[:]
    zeroInDegree_copy = zeroInDegree[:]
    chromosome = Chromosome([VM(0, 0)] * numberOfTasks, [0] * numberOfTasks)
    FT = np.zeros((numberOfProcessors, numberOfTasks))
    FT_thu = np.zeros(numberOfTasks)
    processor = [VM(0, 0)] * numberOfTasks
    FTofTasks = [0] * numberOfTasks
    i = 0

    while(len(zeroInDegree_copy) > 0):
        index_task = random.randint(0, len(zeroInDegree_copy) - 1)
        task = zeroInDegree_copy[index_task]

        find = False
        choosen = VM(0, 0)

        for typed in range(numberOfProcessors):
            if find:
                break
            idd = random.randint(0, numberOfTasks - 1)
            FT_thu[task] = 0
            DAT_processor = 0.0
            for k in range(len(workflow.tasks[task].sources)):
                parentTask = workflow.tasks[task].sources[k]
                DAT_processor = max(DAT_processor, FTofTasks[parentTask] + ((workflow.DAG[parentTask][task] / network) if diff(processor[task], processor[parentTask]) else 0.0))
            FT_thu[task] = max(DAT_processor, FT[typed][idd]) + computationTime[task][typed]
            if FT_thu[task] <= workflow.subDeadline[task]:
                find = True
                choosen = VM(typed, idd)
        if find == False:
            choosen = VM(random.randint(0, numberOfProcessors - 1), idd)


        chromosome.tasks[i] = task
        chromosome.processors[i] = choosen
        processor[task] = choosen
        FT[choosen.typed][choosen.idd] = FT_thu[task]
        FTofTasks[task] = FT_thu[task]

        zeroInDegree_copy.pop(index_task)
        for j in range(len(workflow.tasks[task].destinations)):
            adj = workflow.tasks[task].destinations[j]
            inDegree_copy[adj] -= 1
            if inDegree_copy[adj] == 0:
                zeroInDegree_copy.append(adj)
        i += 1

    #multi thread
    chromosome.cal_fitness()
    return chromosome

def generateHeuristicPopulation(size, percentage, inDegree, zeroInDegree):
    heuristicPopulation = []
    size = math.ceil(percentage * size)
    for i in range(size):
        chro = createHeuristicChromosome(inDegree, zeroInDegree)
        heuristicPopulation.append(chro)
    return heuristicPopulation

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

rand = 0
rouletteWheel = 1
tournament = 2

class GA:
    def __init__(self, workFlow, populationSize, perRandom, perHeuristic, perElitics, perHC, p_c, p_m):
        self.populationSize = populationSize
        self.worfFlow = workFlow
        self.p_c = p_c
        self.p_m = p_m
        self.maxGeneration = 0
        self.perRandom = perRandom
        self.perHeuristic = perHeuristic
        self.perElitics = perElitics
        self.perHC = perHC
        self.bestGene = 0

        self.population = generateRandomPopulation(populationSize, perRandom, workFlow.inDegree, workFlow.zeroInDegree) + generateHeuristicPopulation(populationSize, perHeuristic, workFlow.inDegree, workFlow.zeroInDegree)
        self.population = quicksort(self.population, isBetter)

    def recombination(self, lenNextGen, typee):
        ng = []
        if typee == rand:
            #used_parents = set()
            start = 0
            while (lenNextGen < self.populationSize):
                '''while True:
                    parents = tuple(random.sample(self.population, 2))
                    if parents not in used_parents:
                        used_parents.add(parents)
                        break'''
                parents = []
                parents.append(self.population[start])
                parents.append(self.population[random.randint(start + 1, len(self.population) - 1)])
                start += 1
                child = Chromosome.crossover(parents[0], parents[1], p_c)
                if child == None:
                    continue
                child0 = child[0].mutate(p_m)
                child1 = child[1].mutate(p_m)
                ng.append(child0)
                ng.append(child1)
                lenNextGen += 2

                child0.cal_fitness()
                child1.cal_fitness()

        if typee == rouletteWheel:
            wheel = copy.deepcopy(self.population)
            lenn = len(wheel)
            weights = [1 / (i + 1) for i in range(len(wheel))]
            total_weight = sum(weights)
            normalized_weights = [w / total_weight for w in weights]
        
            while lenNextGen < self.populationSize:
                if lenn - lenNextGen <= 1:
                    break
                selected_index1 = random.choices(range(len(wheel)), weights=normalized_weights, k=1)[0]
                element1 = wheel[selected_index1]

                selected_index2 = random.choices(range(len(wheel)), weights=normalized_weights, k=1)[0]
                element2 = wheel[selected_index2]

                child = Chromosome.crossover(element1, element2, p_c)
                if child is None:
                    continue

                lenNextGen += 2
                child0 = child[0].mutate(p_m)
                child1 = child[1].mutate(p_m)

                ng.append(child0)
                ng.append(child1)

                # Tính toán song song fitness cho các đứa con
                child0.cal_fitness()
                child1.cal_fitness()

        if typee == tournament:
            while lenNextGen < self.populationSize:
                parent1 = tournamentSelection(random.sample(self.population, 5))
                parent2 = tournamentSelection(random.sample(self.population, 5))

                child = Chromosome.crossover(parent1, parent2, p_c)
                if child is None:
                    continue

                lenNextGen += 2
                child0 = child[0].mutate(p_m)
                child1 = child[1].mutate(p_m)

                ng.append(child0)
                ng.append(child1)

                # Tính toán song song fitness cho các đứa con
                child0.cal_fitness()
                child1.cal_fitness()


        return ng

    def find_solution(self, typee):
        best = Chromosome([VM(0, 0)] * numberOfTasks, [0] * numberOfTasks)
        best.completionTime = 1e8
        best.cost = 1e8
        best.fitness = 1e8
        notImprove = 0
        hold = 0
        sizeElitics = int(self.populationSize * self.perElitics)
        #for gene in range(self.maxGeneration):
        gene = 0
        while gene >= 0:
            gene += 1
            #print(gene)
            nextGen = []
            for i in range(sizeElitics):
                nextGen.append(self.population[i])
            '''for i in range(len(self.population)):
                print(self.population[i].tasks)
                inP(self.population[i])
                print("_____________________________________")

            print(f'_________________________EndGene{gene}______________________________________________')'''
            childd = self.recombination(len(nextGen), typee)
            for i in range(len(childd)):
                nextGen.append(childd[i])
            '''nextGen = quicksort(nextGen, isBetter)
            ss = int(perHC * len(self.population))
            for _ in range(ss):
                selected_index = random.randint(0, len(nextGen) - 1)
                if nextGen[selected_index].isHillClimbing:
                    continue
                else:
                    if nextGen[selected_index].completionTime > workflow.deadline:
                        nextGen[selected_index].isHillClimbing = True
                        nextGen[selected_index] = improveHeuristic(nextGen[selected_index])'''

            '''for i in range(len(nextGen)):
                newC = nextGen[i].self_improve()
                newC.cal_fitness()
                if isBetter(newC, nextGen[i]):
                    nextGen[i] = newC'''

            nextGen = quicksort(nextGen, isBetter)
            if isBetter(nextGen[0], best) == 1:
                self.bestGene = gene
                best = nextGen[0]
                hold = 0
            else:
                hold += 1
            if (hold >=threshHold):
                break

            '''for i in range(len(nextGen)):
                inP(nextGen[i])
                print()
                print("_______________________________________")'''
            self.population = copy.deepcopy(nextGen)

        return best

# %%
import time
workflow = workFlow("D:\WorkFlowTest\dax/Montage_30.xml",  12.38424)
computationTime = []
for i1 in range(workflow.numberOfTasks):
        computationTime.append([])
for i1 in range(workflow.numberOfTasks):
    for jj in range(numberOfProcessors):
        computationTime[i1].append(workflow.tasks[i1].dataSize / (listProcessors[jj].cu))
numberOfTasks = workflow.numberOfTasks
DAG = workflow.DAG
populationSize = 300
perRandom = 0.85
perHeuristic = 0.15
perElitics = 0.5
perHC = 0.6
p_c = 0.95
p_m = 0.02
maxGeneration = 0
threshHold = 75
res = 0
for i in range(5):
    start_time = time.time()
    ga = GA(workflow, populationSize, perRandom, perHeuristic, perElitics, perHC, p_c, p_m)
    sol = ga.find_solution(0)
    end_time = time.time()
    res += sol.cost
    print("++++++ ", sol.completionTime, sol.cost, end_time - start_time, ga.bestGene, " +++++++")
print(res / 5)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# <>:2: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\lminh\AppData\Local\Temp\ipykernel_15232\1128720405.py:2: SyntaxWarning: invalid escape sequence '\W'
#   workflow = workFlow("D:\WorkFlowTest\dax/Montage_30.xml",  12.38424)
# ++++++  12.363050239290509 5.914999999999999 22.313693523406982 40  +++++++
# ++++++  11.970305162853663 5.305 21.69629192352295 42  +++++++
# ++++++  12.209850701226129 5.085 50.29087591171265 214  +++++++
# ++++++  12.366925419398715 6.229999999999999 21.98038911819458 34  +++++++
# ++++++  12.330460769653321 5.1899999999999995 33.892937421798706 118  +++++++
# 5.544999999999999

# %%
#Algorithm compare

import numpy as np
import pandas as pd
from openpyxl import load_workbook
import os
import time
sizesWorkflow = ["30", "50", "100"]
nameWorkflow = ["/CyberShake", "/Epigenomics", "/LIGO", "/Montage"]
sourceDAX = "D:\WorkFlowTest\dax"
computationTime = []
cheapScheduleCost = np.array([
    [0.12, 0.12, 0.12],
    [0.6, 1.44, 13.56],
    [0.24, 0.48, 0.72],
    #[0.24, 0.48, 0.72],
    [0.12, 0.12, 0.12]
])
fastScheduleMakespan = np.array([[58.367999999999995, 60.58, 65.20400000000001],
    [1124.21, 1553.6480000000001, 5975.6500000000015],
    [267.03600000000006, 282.16, 266.552],
    #[267.03600000000006, 282.16, 266.552],
    [11.302, 14.152000000000001, 17.144000000000002]])
cheapScheduleMakespan = np.array([[760.5299999999999, 1524.5600000000004, 3215.7499999999995],
    [17720.15, 41401.780000000006, 403400.19999999995],
    [6617.0700000000015, 11761.949999999999, 21023.960000000003],
    #[6617.0700000000015, 11761.949999999999, 21023.960000000003],
    [227.74999999999997, 508.64000000000016, 1079.3400000000004]])
populationSize = 300
perRandom = 0.85
perHeuristic = 0.15
perElitics = 0.6
perHC = 0.6
p_c = 0.95
p_m = 0.02
threshHold = 75
result = pd.DataFrame(columns=['name', 'numOfTasks', 'iteration', 'factor', 'isSuccess', 'RunTime', 'Cost', 'bestGene'])

for ti in range(len(nameWorkflow)):
    graphType = nameWorkflow[ti]
    print(graphType)
    factor = 0
    filename = sourceDAX  + graphType

    while(factor <= 0.045):
        factor += 0.005
        factor = round(factor, 3)
        print(factor)
        for si in range(len(sizesWorkflow)):
            numTest = 5
            for test in range(numTest):
                sc = True
                size = sizesWorkflow[si]
                filename1 = filename + "_" + size + ".xml"
                deadline = fastScheduleMakespan[ti][si] + (cheapScheduleMakespan[ti][si] - fastScheduleMakespan[ti][si]) * factor
                print(filename1, deadline)
    
                workflow = workFlow(filename1, deadline)
                computationTime = []
                for i1 in range(workflow.numberOfTasks):
                        computationTime.append([])
                for i1 in range(workflow.numberOfTasks):
                    for jj in range(numberOfProcessors):
                        computationTime[i1].append(workflow.tasks[i1].dataSize / (listProcessors[jj].cu))
                numberOfTasks = workflow.numberOfTasks
                DAG = workflow.DAG
    
                start_time = time.time()
                ga = GA(workflow, populationSize, perRandom, perHeuristic, perElitics, perHC, p_c, p_m)
                sol = ga.find_solution(rand)
                end_time = time.time()
                print("++++++ ", sol.completionTime, sol.cost, end_time - start_time, " +++++++")
                if sol.completionTime > deadline:
                    sc = False
                new_row = {'name': graphType[1:], 'numOfTasks': sizesWorkflow[si], 'iteration': test ,'factor': factor, 'isSuccess': sc, 'RunTime': end_time - start_time, 'Cost': sol.cost, 'bestGene': ga.bestGene}
                print(new_row)
                result = pd.concat([result, pd.DataFrame([new_row])], ignore_index=True)
                result.to_excel("result-all-withoutHC-more5Times.xlsx", index=False)
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\W'
# <>:10: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\lminh\AppData\Local\Temp\ipykernel_16416\575941905.py:10: SyntaxWarning: invalid escape sequence '\W'
#   sourceDAX = "D:\WorkFlowTest\dax"
# /CyberShake
# 0.005
# D:\WorkFlowTest\dax/CyberShake_30.xml 61.878809999999994
# ++++++  61.384375797483656 6.845000000000001 35.23081946372986  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.005, 'isSuccess': True, 'RunTime': 35.23081946372986, 'Cost': 6.845000000000001, 'bestGene': 245}
# D:\WorkFlowTest\dax/CyberShake_30.xml 61.878809999999994
# C:\Users\lminh\AppData\Local\Temp\ipykernel_16416\575941905.py:77: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat([result, pd.DataFrame([new_row])], ignore_index=True)
# ++++++  61.445720171398584 5.430000000000001 53.747480630874634  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.005, 'isSuccess': True, 'RunTime': 53.747480630874634, 'Cost': 5.430000000000001, 'bestGene': 429}
# D:\WorkFlowTest\dax/CyberShake_30.xml 61.878809999999994
# ++++++  61.37213940175374 6.69 26.618465185165405  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.005, 'isSuccess': True, 'RunTime': 26.618465185165405, 'Cost': 6.69, 'bestGene': 170}
# D:\WorkFlowTest\dax/CyberShake_30.xml 61.878809999999994
# ++++++  61.11366165924073 6.5100000000000025 31.403242349624634  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.005, 'isSuccess': True, 'RunTime': 31.403242349624634, 'Cost': 6.5100000000000025, 'bestGene': 211}
# D:\WorkFlowTest\dax/CyberShake_30.xml 61.878809999999994
# ++++++  61.24566165924072 6.315000000000001 36.224520206451416  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.005, 'isSuccess': True, 'RunTime': 36.224520206451416, 'Cost': 6.315000000000001, 'bestGene': 258}
# D:\WorkFlowTest\dax/CyberShake_50.xml 67.8999
# ++++++  70.30816048431397 20.24000000000001 25.840291023254395  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.005, 'isSuccess': False, 'RunTime': 25.840291023254395, 'Cost': 20.24000000000001, 'bestGene': 61}
# D:\WorkFlowTest\dax/CyberShake_50.xml 67.8999
# ++++++  67.61616048431395 11.024999999999993 162.8255820274353  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.005, 'isSuccess': True, 'RunTime': 162.8255820274353, 'Cost': 11.024999999999993, 'bestGene': 831}
# D:\WorkFlowTest\dax/CyberShake_50.xml 67.8999
# ++++++  67.85499214172363 9.305000000000001 176.84905409812927  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.005, 'isSuccess': True, 'RunTime': 176.84905409812927, 'Cost': 9.305000000000001, 'bestGene': 910}
# D:\WorkFlowTest\dax/CyberShake_50.xml 67.8999
# ++++++  69.48816048431397 20.629999999999995 43.34471535682678  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.005, 'isSuccess': False, 'RunTime': 43.34471535682678, 'Cost': 20.629999999999995, 'bestGene': 152}
# D:\WorkFlowTest\dax/CyberShake_50.xml 67.8999
# ++++++  67.87753624916077 10.504999999999999 129.28103923797607  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.005, 'isSuccess': True, 'RunTime': 129.28103923797607, 'Cost': 10.504999999999999, 'bestGene': 654}
# D:\WorkFlowTest\dax/CyberShake_100.xml 80.95673000000001
# ++++++  80.67288070276048 19.750000000000007 436.13207960128784  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.005, 'isSuccess': True, 'RunTime': 436.13207960128784, 'Cost': 19.750000000000007, 'bestGene': 1163}
# D:\WorkFlowTest\dax/CyberShake_100.xml 80.95673000000001
# ++++++  92.57899262746174 27.440000000000033 74.41089296340942  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.005, 'isSuccess': False, 'RunTime': 74.41089296340942, 'Cost': 27.440000000000033, 'bestGene': 114}
# D:\WorkFlowTest\dax/CyberShake_100.xml 80.95673000000001
# ++++++  87.17092968432108 31.465000000000042 84.19085311889648  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.005, 'isSuccess': False, 'RunTime': 84.19085311889648, 'Cost': 31.465000000000042, 'bestGene': 159}
# D:\WorkFlowTest\dax/CyberShake_100.xml 80.95673000000001
# ++++++  92.51813703664142 28.17000000000002 47.053404331207275  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.005, 'isSuccess': False, 'RunTime': 47.053404331207275, 'Cost': 28.17000000000002, 'bestGene': 49}
# D:\WorkFlowTest\dax/CyberShake_100.xml 80.95673000000001
# ++++++  80.94237450626918 21.19000000000001 206.69451522827148  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.005, 'isSuccess': True, 'RunTime': 206.69451522827148, 'Cost': 21.19000000000001, 'bestGene': 504}
# 0.01
# D:\WorkFlowTest\dax/CyberShake_30.xml 65.38962
# ++++++  65.34566165924072 6.100000000000001 27.283896684646606  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.01, 'isSuccess': True, 'RunTime': 27.283896684646606, 'Cost': 6.100000000000001, 'bestGene': 181}
# D:\WorkFlowTest\dax/CyberShake_30.xml 65.38962
# ++++++  65.328875944955 5.54 16.95105290412903  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.01, 'isSuccess': True, 'RunTime': 16.95105290412903, 'Cost': 5.54, 'bestGene': 82}
# D:\WorkFlowTest\dax/CyberShake_30.xml 65.38962
# ++++++  64.57930606842041 5.955000000000002 33.092220306396484  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.01, 'isSuccess': True, 'RunTime': 33.092220306396484, 'Cost': 5.955000000000002, 'bestGene': 237}
# D:\WorkFlowTest\dax/CyberShake_30.xml 65.38962
# ++++++  65.35732832590739 5.44 40.390868186950684  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.01, 'isSuccess': True, 'RunTime': 40.390868186950684, 'Cost': 5.44, 'bestGene': 294}
# D:\WorkFlowTest\dax/CyberShake_30.xml 65.38962
# ++++++  64.71566165924074 6.9 21.453092575073242  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.01, 'isSuccess': True, 'RunTime': 21.453092575073242, 'Cost': 6.9, 'bestGene': 128}
# D:\WorkFlowTest\dax/CyberShake_50.xml 75.2198
# ++++++  75.16599214172363 10.454999999999997 87.74962830543518  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.01, 'isSuccess': True, 'RunTime': 87.74962830543518, 'Cost': 10.454999999999997, 'bestGene': 423}
# D:\WorkFlowTest\dax/CyberShake_50.xml 75.2198
# ++++++  74.94070642743792 9.539999999999997 55.96361207962036  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.01, 'isSuccess': True, 'RunTime': 55.96361207962036, 'Cost': 9.539999999999997, 'bestGene': 244}
# D:\WorkFlowTest\dax/CyberShake_50.xml 75.2198
# ++++++  75.05665880839028 8.23 110.5518012046814  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.01, 'isSuccess': True, 'RunTime': 110.5518012046814, 'Cost': 8.23, 'bestGene': 530}
# D:\WorkFlowTest\dax/CyberShake_50.xml 75.2198
# ++++++  75.13449381764728 9.209999999999997 81.25636792182922  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.01, 'isSuccess': True, 'RunTime': 81.25636792182922, 'Cost': 9.209999999999997, 'bestGene': 380}
# D:\WorkFlowTest\dax/CyberShake_50.xml 75.2198
# ++++++  75.14973191288539 8.604999999999999 61.99455666542053  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.01, 'isSuccess': True, 'RunTime': 61.99455666542053, 'Cost': 8.604999999999999, 'bestGene': 277}
# D:\WorkFlowTest\dax/CyberShake_100.xml 96.70946
# ++++++  96.66408779144287 15.65499999999999 357.6806335449219  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.01, 'isSuccess': True, 'RunTime': 357.6806335449219, 'Cost': 15.65499999999999, 'bestGene': 934}
# D:\WorkFlowTest\dax/CyberShake_100.xml 96.70946
# ++++++  103.42610521909926 24.814999999999998 70.34799456596375  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.01, 'isSuccess': False, 'RunTime': 70.34799456596375, 'Cost': 24.814999999999998, 'bestGene': 116}
# D:\WorkFlowTest\dax/CyberShake_100.xml 96.70946
# ++++++  96.51832744132149 17.93 243.251362323761  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.01, 'isSuccess': True, 'RunTime': 243.251362323761, 'Cost': 17.93, 'bestGene': 612}
# D:\WorkFlowTest\dax/CyberShake_100.xml 96.70946
# ++++++  96.70002529991999 16.579999999999977 207.08387112617493  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.01, 'isSuccess': True, 'RunTime': 207.08387112617493, 'Cost': 16.579999999999977, 'bestGene': 503}
# D:\WorkFlowTest\dax/CyberShake_100.xml 96.70946
# ++++++  96.56629340117318 17.68 278.8673827648163  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.01, 'isSuccess': True, 'RunTime': 278.8673827648163, 'Cost': 17.68, 'bestGene': 699}
# 0.015
# D:\WorkFlowTest\dax/CyberShake_30.xml 68.90042999999999
# ++++++  68.75899499257405 6.000000000000001 17.4840350151062  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.015, 'isSuccess': True, 'RunTime': 17.4840350151062, 'Cost': 6.000000000000001, 'bestGene': 90}
# D:\WorkFlowTest\dax/CyberShake_30.xml 68.90042999999999
# ++++++  66.67370913081697 4.620000000000001 15.599457740783691  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.015, 'isSuccess': True, 'RunTime': 15.599457740783691, 'Cost': 4.620000000000001, 'bestGene': 67}
# D:\WorkFlowTest\dax/CyberShake_30.xml 68.90042999999999
# ++++++  68.79152020666334 5.165000000000001 36.10711121559143  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.015, 'isSuccess': True, 'RunTime': 36.10711121559143, 'Cost': 5.165000000000001, 'bestGene': 261}
# D:\WorkFlowTest\dax/CyberShake_30.xml 68.90042999999999
# ++++++  68.65066165924073 5.560000000000001 47.22164273262024  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.015, 'isSuccess': True, 'RunTime': 47.22164273262024, 'Cost': 5.560000000000001, 'bestGene': 357}
# D:\WorkFlowTest\dax/CyberShake_30.xml 68.90042999999999
# ++++++  68.80566165924073 4.62 28.680580854415894  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.015, 'isSuccess': True, 'RunTime': 28.680580854415894, 'Cost': 4.62, 'bestGene': 197}
# D:\WorkFlowTest\dax/CyberShake_50.xml 82.53970000000001
# ++++++  82.28116048431397 8.25 95.48336100578308  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.015, 'isSuccess': True, 'RunTime': 95.48336100578308, 'Cost': 8.25, 'bestGene': 456}
# D:\WorkFlowTest\dax/CyberShake_50.xml 82.53970000000001
# ++++++  82.08904937320284 7.900000000000003 78.34520626068115  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.015, 'isSuccess': True, 'RunTime': 78.34520626068115, 'Cost': 7.900000000000003, 'bestGene': 364}
# D:\WorkFlowTest\dax/CyberShake_50.xml 82.53970000000001
# ++++++  82.1408695824941 7.950000000000001 91.28596687316895  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.015, 'isSuccess': True, 'RunTime': 91.28596687316895, 'Cost': 7.950000000000001, 'bestGene': 431}
# D:\WorkFlowTest\dax/CyberShake_50.xml 82.53970000000001
# ++++++  81.41312007904052 9.369999999999997 74.1633768081665  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.015, 'isSuccess': True, 'RunTime': 74.1633768081665, 'Cost': 9.369999999999997, 'bestGene': 341}
# D:\WorkFlowTest\dax/CyberShake_50.xml 82.53970000000001
# ++++++  82.15916048431396 7.705000000000002 95.03867673873901  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.015, 'isSuccess': True, 'RunTime': 95.03867673873901, 'Cost': 7.705000000000002, 'bestGene': 464}
# D:\WorkFlowTest\dax/CyberShake_100.xml 112.46218999999999
# ++++++  112.45721633021037 12.759999999999984 314.35219073295593  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.015, 'isSuccess': True, 'RunTime': 314.35219073295593, 'Cost': 12.759999999999984, 'bestGene': 813}
# D:\WorkFlowTest\dax/CyberShake_100.xml 112.46218999999999
# ++++++  112.17665866851806 15.639999999999985 310.6916582584381  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.015, 'isSuccess': True, 'RunTime': 310.6916582584381, 'Cost': 15.639999999999985, 'bestGene': 801}
# D:\WorkFlowTest\dax/CyberShake_100.xml 112.46218999999999
# ++++++  110.36763703664143 14.259999999999993 307.986545085907  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.015, 'isSuccess': True, 'RunTime': 307.986545085907, 'Cost': 14.259999999999993, 'bestGene': 795}
# D:\WorkFlowTest\dax/CyberShake_100.xml 112.46218999999999
# ++++++  112.37533848190304 15.58499999999998 156.7235107421875  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.015, 'isSuccess': True, 'RunTime': 156.7235107421875, 'Cost': 15.58499999999998, 'bestGene': 368}
# D:\WorkFlowTest\dax/CyberShake_100.xml 112.46218999999999
# ++++++  112.42856343042283 14.654999999999982 234.4636001586914  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.015, 'isSuccess': True, 'RunTime': 234.4636001586914, 'Cost': 14.654999999999982, 'bestGene': 582}
# 0.02
# D:\WorkFlowTest\dax/CyberShake_30.xml 72.41123999999999
# ++++++  71.14970927828833 5.845000000000001 20.882713317871094  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.02, 'isSuccess': True, 'RunTime': 20.882713317871094, 'Cost': 5.845000000000001, 'bestGene': 123}
# D:\WorkFlowTest\dax/CyberShake_30.xml 72.41123999999999
# ++++++  71.54982832590738 5.01 18.985570907592773  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.02, 'isSuccess': True, 'RunTime': 18.985570907592773, 'Cost': 5.01, 'bestGene': 102}
# D:\WorkFlowTest\dax/CyberShake_30.xml 72.41123999999999
# ++++++  71.85752020666334 5.16 21.24555516242981  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.02, 'isSuccess': True, 'RunTime': 21.24555516242981, 'Cost': 5.16, 'bestGene': 130}
# D:\WorkFlowTest\dax/CyberShake_30.xml 72.41123999999999
# ++++++  72.31566165924072 4.605 32.49303364753723  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.02, 'isSuccess': True, 'RunTime': 32.49303364753723, 'Cost': 4.605, 'bestGene': 234}
# D:\WorkFlowTest\dax/CyberShake_30.xml 72.41123999999999
# ++++++  72.23089167049952 4.58 41.85746932029724  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.02, 'isSuccess': True, 'RunTime': 41.85746932029724, 'Cost': 4.58, 'bestGene': 312}
# D:\WorkFlowTest\dax/CyberShake_50.xml 89.8596
# ++++++  89.25753624916076 7.040000000000002 81.52975797653198  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.02, 'isSuccess': True, 'RunTime': 81.52975797653198, 'Cost': 7.040000000000002, 'bestGene': 385}
# D:\WorkFlowTest\dax/CyberShake_50.xml 89.8596
# ++++++  89.68753624916077 7.725000000000003 80.08785200119019  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.02, 'isSuccess': True, 'RunTime': 80.08785200119019, 'Cost': 7.725000000000003, 'bestGene': 377}
# D:\WorkFlowTest\dax/CyberShake_50.xml 89.8596
# ++++++  88.44645341237387 6.830000000000002 77.10458827018738  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.02, 'isSuccess': True, 'RunTime': 77.10458827018738, 'Cost': 6.830000000000002, 'bestGene': 367}
# D:\WorkFlowTest\dax/CyberShake_50.xml 89.8596
# ++++++  89.45978674570718 9.379999999999999 61.88178610801697  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.02, 'isSuccess': True, 'RunTime': 61.88178610801697, 'Cost': 9.379999999999999, 'bestGene': 279}
# D:\WorkFlowTest\dax/CyberShake_50.xml 89.8596
# ++++++  89.38232547505696 9.694999999999997 52.20810890197754  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.02, 'isSuccess': True, 'RunTime': 52.20810890197754, 'Cost': 9.694999999999997, 'bestGene': 219}
# D:\WorkFlowTest\dax/CyberShake_100.xml 128.21492
# ++++++  127.45840492248534 13.344999999999985 265.57116293907166  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.02, 'isSuccess': True, 'RunTime': 265.57116293907166, 'Cost': 13.344999999999985, 'bestGene': 682}
# D:\WorkFlowTest\dax/CyberShake_100.xml 128.21492
# ++++++  127.07263543468052 16.41999999999998 186.770494222641  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.02, 'isSuccess': True, 'RunTime': 186.770494222641, 'Cost': 16.41999999999998, 'bestGene': 452}
# D:\WorkFlowTest\dax/CyberShake_100.xml 128.21492
# ++++++  127.9971029249827 12.269999999999985 271.33470153808594  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.02, 'isSuccess': True, 'RunTime': 271.33470153808594, 'Cost': 12.269999999999985, 'bestGene': 693}
# D:\WorkFlowTest\dax/CyberShake_100.xml 128.21492
# ++++++  126.07339193132188 13.019999999999978 177.77950954437256  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.02, 'isSuccess': True, 'RunTime': 177.77950954437256, 'Cost': 13.019999999999978, 'bestGene': 425}
# D:\WorkFlowTest\dax/CyberShake_100.xml 128.21492
# ++++++  127.99697635105677 10.509999999999994 320.5505361557007  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.02, 'isSuccess': True, 'RunTime': 320.5505361557007, 'Cost': 10.509999999999994, 'bestGene': 840}
# 0.025
# D:\WorkFlowTest\dax/CyberShake_30.xml 75.92204999999998
# ++++++  74.92899499257406 3.8800000000000012 45.042372941970825  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.025, 'isSuccess': True, 'RunTime': 45.042372941970825, 'Cost': 3.8800000000000012, 'bestGene': 344}
# D:\WorkFlowTest\dax/CyberShake_30.xml 75.92204999999998
# ++++++  74.93899499257405 4.29 25.969431400299072  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.025, 'isSuccess': True, 'RunTime': 25.969431400299072, 'Cost': 4.29, 'bestGene': 165}
# D:\WorkFlowTest\dax/CyberShake_30.xml 75.92204999999998
# ++++++  73.93005833716619 4.375000000000001 29.79208254814148  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.025, 'isSuccess': True, 'RunTime': 29.79208254814148, 'Cost': 4.375000000000001, 'bestGene': 202}
# D:\WorkFlowTest\dax/CyberShake_30.xml 75.92204999999998
# ++++++  72.09898690859475 4.425000000000001 19.08436107635498  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.025, 'isSuccess': True, 'RunTime': 19.08436107635498, 'Cost': 4.425000000000001, 'bestGene': 100}
# D:\WorkFlowTest\dax/CyberShake_30.xml 75.92204999999998
# ++++++  73.70566165924072 4.265 30.842772245407104  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.025, 'isSuccess': True, 'RunTime': 30.842772245407104, 'Cost': 4.265, 'bestGene': 211}
# D:\WorkFlowTest\dax/CyberShake_50.xml 97.17950000000002
# ++++++  96.94868065834045 7.26 45.19678258895874  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.025, 'isSuccess': True, 'RunTime': 45.19678258895874, 'Cost': 7.26, 'bestGene': 184}
# D:\WorkFlowTest\dax/CyberShake_50.xml 97.17950000000002
# ++++++  95.48330334145682 6.715000000000003 48.76420187950134  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.025, 'isSuccess': True, 'RunTime': 48.76420187950134, 'Cost': 6.715000000000003, 'bestGene': 196}
# D:\WorkFlowTest\dax/CyberShake_50.xml 97.17950000000002
# ++++++  96.16353624916077 6.960000000000003 63.605952739715576  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.025, 'isSuccess': True, 'RunTime': 63.605952739715576, 'Cost': 6.960000000000003, 'bestGene': 284}
# D:\WorkFlowTest\dax/CyberShake_50.xml 97.17950000000002
# ++++++  96.39968065834046 7.120000000000002 88.5055525302887  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.025, 'isSuccess': True, 'RunTime': 88.5055525302887, 'Cost': 7.120000000000002, 'bestGene': 422}
# D:\WorkFlowTest\dax/CyberShake_50.xml 97.17950000000002
# ++++++  96.65516048431397 6.395000000000002 85.0224826335907  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.025, 'isSuccess': True, 'RunTime': 85.0224826335907, 'Cost': 6.395000000000002, 'bestGene': 404}
# D:\WorkFlowTest\dax/CyberShake_100.xml 143.96765
# ++++++  139.11074076016743 11.469999999999988 163.39861917495728  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.025, 'isSuccess': True, 'RunTime': 163.39861917495728, 'Cost': 11.469999999999988, 'bestGene': 386}
# D:\WorkFlowTest\dax/CyberShake_100.xml 143.96765
# ++++++  138.60472507667544 11.869999999999989 234.57933115959167  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.025, 'isSuccess': True, 'RunTime': 234.57933115959167, 'Cost': 11.869999999999989, 'bestGene': 587}
# D:\WorkFlowTest\dax/CyberShake_100.xml 143.96765
# ++++++  135.1040877914429 14.439999999999989 146.32842874526978  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.025, 'isSuccess': True, 'RunTime': 146.32842874526978, 'Cost': 14.439999999999989, 'bestGene': 339}
# D:\WorkFlowTest\dax/CyberShake_100.xml 143.96765
# ++++++  142.52241321245828 10.474999999999989 278.287246465683  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.025, 'isSuccess': True, 'RunTime': 278.287246465683, 'Cost': 10.474999999999989, 'bestGene': 702}
# D:\WorkFlowTest\dax/CyberShake_100.xml 143.96765
# ++++++  140.36794811248777 12.249999999999982 203.154611825943  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.025, 'isSuccess': True, 'RunTime': 203.154611825943, 'Cost': 12.249999999999982, 'bestGene': 498}
# 0.03
# D:\WorkFlowTest\dax/CyberShake_30.xml 79.43285999999999
# ++++++  78.57148690859476 3.62 42.67577505111694  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.03, 'isSuccess': True, 'RunTime': 42.67577505111694, 'Cost': 3.62, 'bestGene': 321}
# D:\WorkFlowTest\dax/CyberShake_30.xml 79.43285999999999
# ++++++  78.48899499257405 4.015 35.81723356246948  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.03, 'isSuccess': True, 'RunTime': 35.81723356246948, 'Cost': 4.015, 'bestGene': 265}
# D:\WorkFlowTest\dax/CyberShake_30.xml 79.43285999999999
# ++++++  76.57232832590739 4.025 33.761865854263306  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.03, 'isSuccess': True, 'RunTime': 33.761865854263306, 'Cost': 4.025, 'bestGene': 241}
# D:\WorkFlowTest\dax/CyberShake_30.xml 79.43285999999999
# ++++++  76.46566165924072 4.154999999999999 19.192058086395264  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.03, 'isSuccess': True, 'RunTime': 19.192058086395264, 'Cost': 4.154999999999999, 'bestGene': 97}
# D:\WorkFlowTest\dax/CyberShake_30.xml 79.43285999999999
# ++++++  79.25566165924073 4.2749999999999995 24.67641282081604  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.03, 'isSuccess': True, 'RunTime': 24.67641282081604, 'Cost': 4.2749999999999995, 'bestGene': 155}
# D:\WorkFlowTest\dax/CyberShake_50.xml 104.49940000000001
# ++++++  103.50100485822888 7.130000000000002 39.462656021118164  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.03, 'isSuccess': True, 'RunTime': 39.462656021118164, 'Cost': 7.130000000000002, 'bestGene': 151}
# D:\WorkFlowTest\dax/CyberShake_50.xml 104.49940000000001
# ++++++  104.15699214172365 5.385000000000001 85.43651628494263  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.03, 'isSuccess': True, 'RunTime': 85.43651628494263, 'Cost': 5.385000000000001, 'bestGene': 405}
# D:\WorkFlowTest\dax/CyberShake_50.xml 104.49940000000001
# ++++++  104.45868065834046 6.190000000000002 52.829113245010376  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.03, 'isSuccess': True, 'RunTime': 52.829113245010376, 'Cost': 6.190000000000002, 'bestGene': 226}
# D:\WorkFlowTest\dax/CyberShake_50.xml 104.49940000000001
# ++++++  103.5584938176473 6.100000000000002 96.25025153160095  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.03, 'isSuccess': True, 'RunTime': 96.25025153160095, 'Cost': 6.100000000000002, 'bestGene': 468}
# D:\WorkFlowTest\dax/CyberShake_50.xml 104.49940000000001
# ++++++  103.67312007904053 5.865000000000002 81.76296901702881  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.03, 'isSuccess': True, 'RunTime': 81.76296901702881, 'Cost': 5.865000000000002, 'bestGene': 385}
# D:\WorkFlowTest\dax/CyberShake_100.xml 159.72037999999998
# ++++++  158.57724962827896 11.429999999999984 248.16455078125  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.03, 'isSuccess': True, 'RunTime': 248.16455078125, 'Cost': 11.429999999999984, 'bestGene': 623}
# D:\WorkFlowTest\dax/CyberShake_100.xml 159.72037999999998
# ++++++  158.76075445810955 10.369999999999994 147.81951189041138  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.03, 'isSuccess': True, 'RunTime': 147.81951189041138, 'Cost': 10.369999999999994, 'bestGene': 340}
# D:\WorkFlowTest\dax/CyberShake_100.xml 159.72037999999998
# ++++++  157.1028826649984 10.68999999999999 256.7472424507141  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.03, 'isSuccess': True, 'RunTime': 256.7472424507141, 'Cost': 10.68999999999999, 'bestGene': 651}
# D:\WorkFlowTest\dax/CyberShake_100.xml 159.72037999999998
# ++++++  158.03280307769774 9.209999999999997 242.8805170059204  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.03, 'isSuccess': True, 'RunTime': 242.8805170059204, 'Cost': 9.209999999999997, 'bestGene': 612}
# D:\WorkFlowTest\dax/CyberShake_100.xml 159.72037999999998
# ++++++  157.9337630176544 10.559999999999988 192.885183095932  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.03, 'isSuccess': True, 'RunTime': 192.885183095932, 'Cost': 10.559999999999988, 'bestGene': 468}
# 0.035
# D:\WorkFlowTest\dax/CyberShake_30.xml 82.94367
# ++++++  82.28347273508706 3.8350000000000004 10.846272468566895  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.035, 'isSuccess': True, 'RunTime': 10.846272468566895, 'Cost': 3.8350000000000004, 'bestGene': 26}
# D:\WorkFlowTest\dax/CyberShake_30.xml 82.94367
# ++++++  82.38929798444113 4.1899999999999995 16.753702640533447  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.035, 'isSuccess': True, 'RunTime': 16.753702640533447, 'Cost': 4.1899999999999995, 'bestGene': 79}
# D:\WorkFlowTest\dax/CyberShake_30.xml 82.94367
# ++++++  81.8306616592407 4.0600000000000005 21.73380970954895  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.035, 'isSuccess': True, 'RunTime': 21.73380970954895, 'Cost': 4.0600000000000005, 'bestGene': 133}
# D:\WorkFlowTest\dax/CyberShake_30.xml 82.94367
# ++++++  82.57399499257404 4.03 16.093485832214355  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.035, 'isSuccess': True, 'RunTime': 16.093485832214355, 'Cost': 4.03, 'bestGene': 73}
# D:\WorkFlowTest\dax/CyberShake_30.xml 82.94367
# ++++++  80.90451725006102 3.83 28.336005687713623  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.035, 'isSuccess': True, 'RunTime': 28.336005687713623, 'Cost': 3.83, 'bestGene': 186}
# D:\WorkFlowTest\dax/CyberShake_50.xml 111.81930000000003
# ++++++  108.49200821685791 6.865 74.08823561668396  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.035, 'isSuccess': True, 'RunTime': 74.08823561668396, 'Cost': 6.865, 'bestGene': 342}
# D:\WorkFlowTest\dax/CyberShake_50.xml 111.81930000000003
# ++++++  109.12099214172362 6.575000000000002 60.2274706363678  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.035, 'isSuccess': True, 'RunTime': 60.2274706363678, 'Cost': 6.575000000000002, 'bestGene': 257}
# D:\WorkFlowTest\dax/CyberShake_50.xml 111.81930000000003
# ++++++  111.5154938176473 7.530000000000004 26.26926350593567  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.035, 'isSuccess': True, 'RunTime': 26.26926350593567, 'Cost': 7.530000000000004, 'bestGene': 70}
# D:\WorkFlowTest\dax/CyberShake_50.xml 111.81930000000003
# ++++++  110.46926448822022 6.500000000000002 66.22321581840515  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.035, 'isSuccess': True, 'RunTime': 66.22321581840515, 'Cost': 6.500000000000002, 'bestGene': 297}
# D:\WorkFlowTest\dax/CyberShake_50.xml 111.81930000000003
# ++++++  111.14153780119759 5.515000000000002 99.15602898597717  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.035, 'isSuccess': True, 'RunTime': 99.15602898597717, 'Cost': 5.515000000000002, 'bestGene': 484}
# D:\WorkFlowTest\dax/CyberShake_100.xml 175.47311
# ++++++  165.81907987912496 11.47999999999998 194.89402318000793  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.035, 'isSuccess': True, 'RunTime': 194.89402318000793, 'Cost': 11.47999999999998, 'bestGene': 472}
# D:\WorkFlowTest\dax/CyberShake_100.xml 175.47311
# ++++++  170.98013703664142 10.05499999999999 282.7175967693329  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.035, 'isSuccess': True, 'RunTime': 282.7175967693329, 'Cost': 10.05499999999999, 'bestGene': 726}
# D:\WorkFlowTest\dax/CyberShake_100.xml 175.47311
# ++++++  164.56728082021075 10.379999999999988 247.5309510231018  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.035, 'isSuccess': True, 'RunTime': 247.5309510231018, 'Cost': 10.379999999999988, 'bestGene': 627}
# D:\WorkFlowTest\dax/CyberShake_100.xml 175.47311
# ++++++  171.9314703699748 9.939999999999992 225.7992606163025  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.035, 'isSuccess': True, 'RunTime': 225.7992606163025, 'Cost': 9.939999999999992, 'bestGene': 563}
# D:\WorkFlowTest\dax/CyberShake_100.xml 175.47311
# ++++++  168.61781846682229 10.399999999999984 285.269268989563  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.035, 'isSuccess': True, 'RunTime': 285.269268989563, 'Cost': 10.399999999999984, 'bestGene': 729}
# 0.04
# D:\WorkFlowTest\dax/CyberShake_30.xml 86.45447999999999
# ++++++  84.2219504776001 4.260000000000001 12.647817850112915  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.04, 'isSuccess': True, 'RunTime': 12.647817850112915, 'Cost': 4.260000000000001, 'bestGene': 45}
# D:\WorkFlowTest\dax/CyberShake_30.xml 86.45447999999999
# ++++++  85.89648690859477 4.9350000000000005 18.095699071884155  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.04, 'isSuccess': True, 'RunTime': 18.095699071884155, 'Cost': 4.9350000000000005, 'bestGene': 96}
# D:\WorkFlowTest\dax/CyberShake_30.xml 86.45447999999999
# ++++++  84.63679798444112 4.164999999999999 31.59945511817932  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.04, 'isSuccess': True, 'RunTime': 31.59945511817932, 'Cost': 4.164999999999999, 'bestGene': 218}
# D:\WorkFlowTest\dax/CyberShake_30.xml 86.45447999999999
# ++++++  85.19430606842042 4.46 11.616954565048218  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.04, 'isSuccess': True, 'RunTime': 11.616954565048218, 'Cost': 4.46, 'bestGene': 33}
# D:\WorkFlowTest\dax/CyberShake_30.xml 86.45447999999999
# ++++++  83.1696949573093 3.74 10.981964349746704  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.04, 'isSuccess': True, 'RunTime': 10.981964349746704, 'Cost': 3.74, 'bestGene': 29}
# D:\WorkFlowTest\dax/CyberShake_50.xml 119.13920000000002
# ++++++  118.71312007904054 6.010000000000002 49.17257332801819  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.04, 'isSuccess': True, 'RunTime': 49.17257332801819, 'Cost': 6.010000000000002, 'bestGene': 198}
# D:\WorkFlowTest\dax/CyberShake_50.xml 119.13920000000002
# ++++++  118.46349381764729 4.690000000000001 101.79260754585266  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.04, 'isSuccess': True, 'RunTime': 101.79260754585266, 'Cost': 4.690000000000001, 'bestGene': 498}
# D:\WorkFlowTest\dax/CyberShake_50.xml 119.13920000000002
# ++++++  116.30953624916076 7.0550000000000015 53.43021512031555  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.04, 'isSuccess': True, 'RunTime': 53.43021512031555, 'Cost': 7.0550000000000015, 'bestGene': 231}
# D:\WorkFlowTest\dax/CyberShake_50.xml 119.13920000000002
# ++++++  118.3650630496797 6.700000000000003 55.85776400566101  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.04, 'isSuccess': True, 'RunTime': 55.85776400566101, 'Cost': 6.700000000000003, 'bestGene': 236}
# D:\WorkFlowTest\dax/CyberShake_50.xml 119.13920000000002
# ++++++  118.11949381764731 6.755000000000001 70.2874071598053  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.04, 'isSuccess': True, 'RunTime': 70.2874071598053, 'Cost': 6.755000000000001, 'bestGene': 322}
# D:\WorkFlowTest\dax/CyberShake_100.xml 191.22584
# ++++++  188.6387630176544 9.499999999999996 118.91377019882202  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.04, 'isSuccess': True, 'RunTime': 118.91377019882202, 'Cost': 9.499999999999996, 'bestGene': 261}
# D:\WorkFlowTest\dax/CyberShake_100.xml 191.22584
# ++++++  189.90628144582112 8.889999999999999 252.24480175971985  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.04, 'isSuccess': True, 'RunTime': 252.24480175971985, 'Cost': 8.889999999999999, 'bestGene': 638}
# D:\WorkFlowTest\dax/CyberShake_100.xml 191.22584
# ++++++  190.05461477915446 9.225 177.72369384765625  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.04, 'isSuccess': True, 'RunTime': 177.72369384765625, 'Cost': 9.225, 'bestGene': 425}
# D:\WorkFlowTest\dax/CyberShake_100.xml 191.22584
# ++++++  187.97876301765442 9.094999999999997 201.07050895690918  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.04, 'isSuccess': True, 'RunTime': 201.07050895690918, 'Cost': 9.094999999999997, 'bestGene': 492}
# D:\WorkFlowTest\dax/CyberShake_100.xml 191.22584
# ++++++  189.1687630176544 8.160000000000004 177.31191563606262  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.04, 'isSuccess': True, 'RunTime': 177.31191563606262, 'Cost': 8.160000000000004, 'bestGene': 420}
# 0.045
# D:\WorkFlowTest\dax/CyberShake_30.xml 89.96528999999998
# ++++++  89.23548690859477 3.305 25.2567241191864  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.045, 'isSuccess': True, 'RunTime': 25.2567241191864, 'Cost': 3.305, 'bestGene': 164}
# D:\WorkFlowTest\dax/CyberShake_30.xml 89.96528999999998
# ++++++  89.77080606842041 4.26 10.909539699554443  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.045, 'isSuccess': True, 'RunTime': 10.909539699554443, 'Cost': 4.26, 'bestGene': 26}
# D:\WorkFlowTest\dax/CyberShake_30.xml 89.96528999999998
# ++++++  88.62185679154167 4.62 8.18762731552124  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.045, 'isSuccess': True, 'RunTime': 8.18762731552124, 'Cost': 4.62, 'bestGene': 1}
# D:\WorkFlowTest\dax/CyberShake_30.xml 89.96528999999998
# ++++++  86.60786941301254 4.02 9.915173768997192  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.045, 'isSuccess': True, 'RunTime': 9.915173768997192, 'Cost': 4.02, 'bestGene': 19}
# D:\WorkFlowTest\dax/CyberShake_30.xml 89.96528999999998
# ++++++  89.9343060684204 3.1900000000000004 40.78051686286926  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.045, 'isSuccess': True, 'RunTime': 40.78051686286926, 'Cost': 3.1900000000000004, 'bestGene': 310}
# D:\WorkFlowTest\dax/CyberShake_50.xml 126.45910000000002
# ++++++  110.20153780119759 6.715000000000002 26.748888969421387  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.045, 'isSuccess': True, 'RunTime': 26.748888969421387, 'Cost': 6.715000000000002, 'bestGene': 72}
# D:\WorkFlowTest\dax/CyberShake_50.xml 126.45910000000002
# ++++++  125.27068065834045 5.530000000000002 55.23476028442383  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.045, 'isSuccess': True, 'RunTime': 55.23476028442383, 'Cost': 5.530000000000002, 'bestGene': 237}
# D:\WorkFlowTest\dax/CyberShake_50.xml 126.45910000000002
# ++++++  115.85216048431394 5.275000000000001 90.62437605857849  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.045, 'isSuccess': True, 'RunTime': 90.62437605857849, 'Cost': 5.275000000000001, 'bestGene': 433}
# D:\WorkFlowTest\dax/CyberShake_50.xml 126.45910000000002
# ++++++  124.89312007904053 6.6750000000000025 41.396509885787964  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.045, 'isSuccess': True, 'RunTime': 41.396509885787964, 'Cost': 6.6750000000000025, 'bestGene': 159}
# D:\WorkFlowTest\dax/CyberShake_50.xml 126.45910000000002
# ++++++  117.68226448822021 5.165000000000001 27.572731971740723  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.045, 'isSuccess': True, 'RunTime': 27.572731971740723, 'Cost': 5.165000000000001, 'bestGene': 79}
# D:\WorkFlowTest\dax/CyberShake_100.xml 206.97856999999996
# ++++++  202.93014991624017 14.419999999999995 109.87891006469727  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.045, 'isSuccess': True, 'RunTime': 109.87891006469727, 'Cost': 14.419999999999995, 'bestGene': 232}
# D:\WorkFlowTest\dax/CyberShake_100.xml 206.97856999999996
# ++++++  206.43376959164937 9.964999999999993 139.57292437553406  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.045, 'isSuccess': True, 'RunTime': 139.57292437553406, 'Cost': 9.964999999999993, 'bestGene': 321}
# D:\WorkFlowTest\dax/CyberShake_100.xml 206.97856999999996
# ++++++  202.5539474868774 10.344999999999988 182.6345989704132  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.045, 'isSuccess': True, 'RunTime': 182.6345989704132, 'Cost': 10.344999999999988, 'bestGene': 443}
# D:\WorkFlowTest\dax/CyberShake_100.xml 206.97856999999996
# ++++++  206.43376959164937 9.609999999999992 190.19674730300903  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.045, 'isSuccess': True, 'RunTime': 190.19674730300903, 'Cost': 9.609999999999992, 'bestGene': 459}
# D:\WorkFlowTest\dax/CyberShake_100.xml 206.97856999999996
# ++++++  195.30066887174334 9.099999999999996 202.11883020401  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.045, 'isSuccess': True, 'RunTime': 202.11883020401, 'Cost': 9.099999999999996, 'bestGene': 495}
# 0.05
# D:\WorkFlowTest\dax/CyberShake_30.xml 93.47609999999999
# ++++++  93.09709023066928 3.7750000000000004 28.342830181121826  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.05, 'isSuccess': True, 'RunTime': 28.342830181121826, 'Cost': 3.7750000000000004, 'bestGene': 193}
# D:\WorkFlowTest\dax/CyberShake_30.xml 93.47609999999999
# ++++++  87.33566165924071 3.0500000000000003 26.301941394805908  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.05, 'isSuccess': True, 'RunTime': 26.301941394805908, 'Cost': 3.0500000000000003, 'bestGene': 174}
# D:\WorkFlowTest\dax/CyberShake_30.xml 93.47609999999999
# ++++++  92.45517738478522 3.5699999999999994 17.20644998550415  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.05, 'isSuccess': True, 'RunTime': 17.20644998550415, 'Cost': 3.5699999999999994, 'bestGene': 92}
# D:\WorkFlowTest\dax/CyberShake_30.xml 93.47609999999999
# ++++++  92.78482024192807 3.8950000000000005 32.041566610336304  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.05, 'isSuccess': True, 'RunTime': 32.041566610336304, 'Cost': 3.8950000000000005, 'bestGene': 222}
# D:\WorkFlowTest\dax/CyberShake_30.xml 93.47609999999999
# ++++++  91.40376155344644 3.26 39.93818688392639  +++++++
# {'name': 'CyberShake', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.05, 'isSuccess': True, 'RunTime': 39.93818688392639, 'Cost': 3.26, 'bestGene': 292}
# D:\WorkFlowTest\dax/CyberShake_50.xml 133.77900000000002
# ++++++  128.0061365509033 6.585000000000001 27.44354510307312  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.05, 'isSuccess': True, 'RunTime': 27.44354510307312, 'Cost': 6.585000000000001, 'bestGene': 79}
# D:\WorkFlowTest\dax/CyberShake_50.xml 133.77900000000002
# ++++++  128.72092549314954 8.325 35.213277101516724  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.05, 'isSuccess': True, 'RunTime': 35.213277101516724, 'Cost': 8.325, 'bestGene': 123}
# D:\WorkFlowTest\dax/CyberShake_50.xml 133.77900000000002
# ++++++  128.89165880839033 5.07 55.06794500350952  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.05, 'isSuccess': True, 'RunTime': 55.06794500350952, 'Cost': 5.07, 'bestGene': 231}
# D:\WorkFlowTest\dax/CyberShake_50.xml 133.77900000000002
# ++++++  132.78449173418682 5.215000000000001 33.73766899108887  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.05, 'isSuccess': True, 'RunTime': 33.73766899108887, 'Cost': 5.215000000000001, 'bestGene': 115}
# D:\WorkFlowTest\dax/CyberShake_50.xml 133.77900000000002
# ++++++  120.93835238865444 4.940000000000001 61.268494606018066  +++++++
# {'name': 'CyberShake', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.05, 'isSuccess': True, 'RunTime': 61.268494606018066, 'Cost': 4.940000000000001, 'bestGene': 270}
# D:\WorkFlowTest\dax/CyberShake_100.xml 222.73129999999998
# ++++++  222.1568037033081 8.025000000000004 102.87442922592163  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.05, 'isSuccess': True, 'RunTime': 102.87442922592163, 'Cost': 8.025000000000004, 'bestGene': 214}
# D:\WorkFlowTest\dax/CyberShake_100.xml 222.73129999999998
# ++++++  221.2565496635437 7.635000000000004 139.4464168548584  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.05, 'isSuccess': True, 'RunTime': 139.4464168548584, 'Cost': 7.635000000000004, 'bestGene': 318}
# D:\WorkFlowTest\dax/CyberShake_100.xml 222.73129999999998
# ++++++  222.23654966354368 8.265000000000002 155.00798296928406  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.05, 'isSuccess': True, 'RunTime': 155.00798296928406, 'Cost': 8.265000000000002, 'bestGene': 364}
# D:\WorkFlowTest\dax/CyberShake_100.xml 222.73129999999998
# ++++++  222.1568037033081 7.285000000000004 155.06179285049438  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.05, 'isSuccess': True, 'RunTime': 155.06179285049438, 'Cost': 7.285000000000004, 'bestGene': 362}
# D:\WorkFlowTest\dax/CyberShake_100.xml 222.73129999999998
# ++++++  220.5565496635437 9.109999999999998 151.47889304161072  +++++++
# {'name': 'CyberShake', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.05, 'isSuccess': True, 'RunTime': 151.47889304161072, 'Cost': 9.109999999999998, 'bestGene': 352}
# /Epigenomics
# 0.005
# D:\WorkFlowTest\dax/Epigenomics_30.xml 1207.1897000000001
# ++++++  1177.9772064098781 4.41 13.456208944320679  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.005, 'isSuccess': True, 'RunTime': 13.456208944320679, 'Cost': 4.41, 'bestGene': 81}
# D:\WorkFlowTest\dax/Epigenomics_30.xml 1207.1897000000001
# ++++++  1186.419801878399 4.37 10.82797646522522  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.005, 'isSuccess': True, 'RunTime': 10.82797646522522, 'Cost': 4.37, 'bestGene': 50}
# D:\WorkFlowTest\dax/Epigenomics_30.xml 1207.1897000000001
# ++++++  1198.1490574364134 4.61 13.174350500106812  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.005, 'isSuccess': True, 'RunTime': 13.174350500106812, 'Cost': 4.61, 'bestGene': 81}
# D:\WorkFlowTest\dax/Epigenomics_30.xml 1207.1897000000001
# ++++++  1195.7499003395503 4.25 15.066162347793579  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.005, 'isSuccess': True, 'RunTime': 15.066162347793579, 'Cost': 4.25, 'bestGene': 106}
# D:\WorkFlowTest\dax/Epigenomics_30.xml 1207.1897000000001
# ++++++  1192.783795944002 4.130000000000001 18.94308090209961  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.005, 'isSuccess': True, 'RunTime': 18.94308090209961, 'Cost': 4.130000000000001, 'bestGene': 154}
# D:\WorkFlowTest\dax/Epigenomics_50.xml 1752.88866
# ++++++  1752.4051315350005 8.62 34.77787184715271  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.005, 'isSuccess': True, 'RunTime': 34.77787184715271, 'Cost': 8.62, 'bestGene': 141}
# D:\WorkFlowTest\dax/Epigenomics_50.xml 1752.88866
# ++++++  1750.1338867672816 7.769999999999999 20.172117233276367  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.005, 'isSuccess': True, 'RunTime': 20.172117233276367, 'Cost': 7.769999999999999, 'bestGene': 47}
# D:\WorkFlowTest\dax/Epigenomics_50.xml 1752.88866
# ++++++  1745.5452609219024 8.865 22.07407855987549  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.005, 'isSuccess': True, 'RunTime': 22.07407855987549, 'Cost': 8.865, 'bestGene': 61}
# D:\WorkFlowTest\dax/Epigenomics_50.xml 1752.88866
# ++++++  1752.1251315350005 8.82 22.013686656951904  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.005, 'isSuccess': True, 'RunTime': 22.013686656951904, 'Cost': 8.82, 'bestGene': 59}
# D:\WorkFlowTest\dax/Epigenomics_50.xml 1752.88866
# ++++++  1752.54008833643 8.245 36.49426245689392  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.005, 'isSuccess': True, 'RunTime': 36.49426245689392, 'Cost': 8.245, 'bestGene': 151}
# D:\WorkFlowTest\dax/Epigenomics_100.xml 7962.772750000001
# ++++++  7797.680653850555 27.555 122.6692123413086  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.005, 'isSuccess': True, 'RunTime': 122.6692123413086, 'Cost': 27.555, 'bestGene': 283}
# D:\WorkFlowTest\dax/Epigenomics_100.xml 7962.772750000001
# ++++++  7933.49962594223 26.900000000000002 142.03711318969727  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.005, 'isSuccess': True, 'RunTime': 142.03711318969727, 'Cost': 26.900000000000002, 'bestGene': 337}
# D:\WorkFlowTest\dax/Epigenomics_100.xml 7962.772750000001
# ++++++  7797.680653850555 27.495000000000005 76.2859001159668  +++++++
# {'name': 'Epigenomics', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.005, 'isSuccess': True, 'RunTime': 76.2859001159668, 'Cost': 27.495000000000005, 'bestGene': 147}
# D:\WorkFlowTest\dax/Epigenomics_100.xml 7962.772750000001
# ++++++  7797.680653850555 27.63500000000001 48.23396706581116  +++++++
# ...
# D:\WorkFlowTest\dax/Montage_30.xml 18.877679999999998
# ++++++  18.842037015914915 5.25 14.6078200340271  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.035, 'isSuccess': True, 'RunTime': 14.6078200340271, 'Cost': 5.25, 'bestGene': 72}
# D:\WorkFlowTest\dax/Montage_50.xml 31.459080000000007
# ++++++  31.41191185360863 8.965000000000005 22.40143609046936  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.035, 'isSuccess': True, 'RunTime': 22.40143609046936, 'Cost': 8.965000000000005, 'bestGene': 48}
# D:\WorkFlowTest\dax/Montage_50.xml 31.459080000000007
# ++++++  31.07556211471558 5.730000000000002 76.91292428970337  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.035, 'isSuccess': True, 'RunTime': 76.91292428970337, 'Cost': 5.730000000000002, 'bestGene': 344}
# D:\WorkFlowTest\dax/Montage_50.xml 31.459080000000007
# ++++++  31.413578520275298 8.975000000000003 29.73155117034912  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.035, 'isSuccess': True, 'RunTime': 29.73155117034912, 'Cost': 8.975000000000003, 'bestGene': 82}
# D:\WorkFlowTest\dax/Montage_50.xml 31.459080000000007
# ++++++  29.9716056098938 7.7050000000000045 42.27052307128906  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.035, 'isSuccess': True, 'RunTime': 42.27052307128906, 'Cost': 7.7050000000000045, 'bestGene': 152}
# D:\WorkFlowTest\dax/Montage_50.xml 31.459080000000007
# ++++++  30.570079526901246 6.605000000000003 40.395429849624634  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.035, 'isSuccess': True, 'RunTime': 40.395429849624634, 'Cost': 6.605000000000003, 'bestGene': 140}
# D:\WorkFlowTest\dax/Montage_100.xml 54.320860000000025
# ++++++  52.77117344220481 10.125000000000004 208.16349267959595  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.035, 'isSuccess': True, 'RunTime': 208.16349267959595, 'Cost': 10.125000000000004, 'bestGene': 483}
# D:\WorkFlowTest\dax/Montage_100.xml 54.320860000000025
# ++++++  53.9098910790398 10.680000000000003 110.37469410896301  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.035, 'isSuccess': True, 'RunTime': 110.37469410896301, 'Cost': 10.680000000000003, 'bestGene': 219}
# D:\WorkFlowTest\dax/Montage_100.xml 54.320860000000025
# ++++++  54.27344368298849 9.420000000000003 191.77759408950806  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.035, 'isSuccess': True, 'RunTime': 191.77759408950806, 'Cost': 9.420000000000003, 'bestGene': 447}
# D:\WorkFlowTest\dax/Montage_100.xml 54.320860000000025
# ++++++  53.300790701548266 10.910000000000004 115.45353841781616  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.035, 'isSuccess': True, 'RunTime': 115.45353841781616, 'Cost': 10.910000000000004, 'bestGene': 237}
# D:\WorkFlowTest\dax/Montage_100.xml 54.320860000000025
# ++++++  54.22699111620586 10.645000000000003 138.82339692115784  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.035, 'isSuccess': True, 'RunTime': 138.82339692115784, 'Cost': 10.645000000000003, 'bestGene': 299}
# 0.04
# D:\WorkFlowTest\dax/Montage_30.xml 19.959919999999997
# ++++++  19.731402535120644 4.45 9.47131872177124  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.04, 'isSuccess': True, 'RunTime': 9.47131872177124, 'Cost': 4.45, 'bestGene': 29}
# D:\WorkFlowTest\dax/Montage_30.xml 19.959919999999997
# ++++++  19.36073586845398 4.63 15.796812534332275  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.04, 'isSuccess': True, 'RunTime': 15.796812534332275, 'Cost': 4.63, 'bestGene': 100}
# D:\WorkFlowTest\dax/Montage_30.xml 19.959919999999997
# ++++++  19.731402535120644 4.45 10.30449891090393  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.04, 'isSuccess': True, 'RunTime': 10.30449891090393, 'Cost': 4.45, 'bestGene': 35}
# D:\WorkFlowTest\dax/Montage_30.xml 19.959919999999997
# ++++++  19.873410839080808 5.29 24.14025354385376  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.04, 'isSuccess': True, 'RunTime': 24.14025354385376, 'Cost': 5.29, 'bestGene': 184}
# D:\WorkFlowTest\dax/Montage_30.xml 19.959919999999997
# ++++++  19.582206315994263 4.135 17.582473039627075  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.04, 'isSuccess': True, 'RunTime': 17.582473039627075, 'Cost': 4.135, 'bestGene': 123}
# D:\WorkFlowTest\dax/Montage_50.xml 33.931520000000006
# ++++++  31.626629850387573 7.575000000000004 31.618656635284424  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.04, 'isSuccess': True, 'RunTime': 31.618656635284424, 'Cost': 7.575000000000004, 'bestGene': 89}
# D:\WorkFlowTest\dax/Montage_50.xml 33.931520000000006
# ++++++  33.50788135256086 8.755000000000004 30.861856698989868  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.04, 'isSuccess': True, 'RunTime': 30.861856698989868, 'Cost': 8.755000000000004, 'bestGene': 90}
# D:\WorkFlowTest\dax/Montage_50.xml 33.931520000000006
# ++++++  33.92953854688009 6.750000000000003 73.29809832572937  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.04, 'isSuccess': True, 'RunTime': 73.29809832572937, 'Cost': 6.750000000000003, 'bestGene': 322}
# D:\WorkFlowTest\dax/Montage_50.xml 33.931520000000006
# ++++++  32.81266887919108 6.770000000000002 70.3400821685791  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.04, 'isSuccess': True, 'RunTime': 70.3400821685791, 'Cost': 6.770000000000002, 'bestGene': 313}
# D:\WorkFlowTest\dax/Montage_50.xml 33.931520000000006
# ++++++  32.45194638379415 7.710000000000003 32.848119497299194  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.04, 'isSuccess': True, 'RunTime': 32.848119497299194, 'Cost': 7.710000000000003, 'bestGene': 103}
# D:\WorkFlowTest\dax/Montage_100.xml 59.63184000000001
# ++++++  58.98887356122336 10.845 92.7830240726471  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.04, 'isSuccess': True, 'RunTime': 92.7830240726471, 'Cost': 10.845, 'bestGene': 174}
# D:\WorkFlowTest\dax/Montage_100.xml 59.63184000000001
# ++++++  58.75836902618409 9.610000000000003 226.86447834968567  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.04, 'isSuccess': True, 'RunTime': 226.86447834968567, 'Cost': 9.610000000000003, 'bestGene': 534}
# D:\WorkFlowTest\dax/Montage_100.xml 59.63184000000001
# ++++++  58.750763372239625 10.610000000000005 79.68086457252502  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.04, 'isSuccess': True, 'RunTime': 79.68086457252502, 'Cost': 10.610000000000005, 'bestGene': 139}
# D:\WorkFlowTest\dax/Montage_100.xml 59.63184000000001
# ++++++  58.627701304753614 9.340000000000003 154.72538828849792  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.04, 'isSuccess': True, 'RunTime': 154.72538828849792, 'Cost': 9.340000000000003, 'bestGene': 341}
# D:\WorkFlowTest\dax/Montage_100.xml 59.63184000000001
# ++++++  59.135712506521315 9.460000000000003 161.242742061615  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.04, 'isSuccess': True, 'RunTime': 161.242742061615, 'Cost': 9.460000000000003, 'bestGene': 359}
# 0.045
# D:\WorkFlowTest\dax/Montage_30.xml 21.04216
# ++++++  20.151402535120642 3.5950000000000006 26.726181745529175  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.045, 'isSuccess': True, 'RunTime': 26.726181745529175, 'Cost': 3.5950000000000006, 'bestGene': 204}
# D:\WorkFlowTest\dax/Montage_30.xml 21.04216
# ++++++  20.882069201787314 4.700000000000001 13.453011512756348  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.045, 'isSuccess': True, 'RunTime': 13.453011512756348, 'Cost': 4.700000000000001, 'bestGene': 68}
# D:\WorkFlowTest\dax/Montage_30.xml 21.04216
# ++++++  20.91273586845398 4.960000000000002 17.8144748210907  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.045, 'isSuccess': True, 'RunTime': 17.8144748210907, 'Cost': 4.960000000000002, 'bestGene': 105}
# D:\WorkFlowTest\dax/Montage_30.xml 21.04216
# ++++++  20.52540253512064 3.875 23.21897792816162  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.045, 'isSuccess': True, 'RunTime': 23.21897792816162, 'Cost': 3.875, 'bestGene': 182}
# D:\WorkFlowTest\dax/Montage_30.xml 21.04216
# ++++++  21.009058999318924 5.920000000000002 16.91683602333069  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.045, 'isSuccess': True, 'RunTime': 16.91683602333069, 'Cost': 5.920000000000002, 'bestGene': 103}
# D:\WorkFlowTest\dax/Montage_50.xml 36.40396000000001
# ++++++  35.165467118308655 6.850000000000003 66.32608723640442  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.045, 'isSuccess': True, 'RunTime': 66.32608723640442, 'Cost': 6.850000000000003, 'bestGene': 281}
# D:\WorkFlowTest\dax/Montage_50.xml 36.40396000000001
# ++++++  36.38812401044936 6.740000000000001 48.702391147613525  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.045, 'isSuccess': True, 'RunTime': 48.702391147613525, 'Cost': 6.740000000000001, 'bestGene': 190}
# D:\WorkFlowTest\dax/Montage_50.xml 36.40396000000001
# ++++++  36.143237581253054 6.930000000000003 36.81959080696106  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.045, 'isSuccess': True, 'RunTime': 36.81959080696106, 'Cost': 6.930000000000003, 'bestGene': 125}
# D:\WorkFlowTest\dax/Montage_50.xml 36.40396000000001
# ++++++  35.925686372333104 7.125000000000002 56.09807538986206  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.045, 'isSuccess': True, 'RunTime': 56.09807538986206, 'Cost': 7.125000000000002, 'bestGene': 221}
# D:\WorkFlowTest\dax/Montage_50.xml 36.40396000000001
# ++++++  36.3265974744161 7.425000000000001 47.55400013923645  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.045, 'isSuccess': True, 'RunTime': 47.55400013923645, 'Cost': 7.425000000000001, 'bestGene': 184}
# D:\WorkFlowTest\dax/Montage_100.xml 64.94282000000001
# ++++++  64.6294436829885 9.745000000000006 84.8610532283783  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.045, 'isSuccess': True, 'RunTime': 84.8610532283783, 'Cost': 9.745000000000006, 'bestGene': 152}
# D:\WorkFlowTest\dax/Montage_100.xml 64.94282000000001
# ++++++  61.07436579961626 8.840000000000002 180.33779621124268  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.045, 'isSuccess': True, 'RunTime': 180.33779621124268, 'Cost': 8.840000000000002, 'bestGene': 415}
# D:\WorkFlowTest\dax/Montage_100.xml 64.94282000000001
# ++++++  63.310537572860724 8.69 166.90034365653992  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.045, 'isSuccess': True, 'RunTime': 166.90034365653992, 'Cost': 8.69, 'bestGene': 355}
# D:\WorkFlowTest\dax/Montage_100.xml 64.94282000000001
# ++++++  64.16403228487289 8.964999999999995 218.75377583503723  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.045, 'isSuccess': True, 'RunTime': 218.75377583503723, 'Cost': 8.964999999999995, 'bestGene': 470}
# D:\WorkFlowTest\dax/Montage_100.xml 64.94282000000001
# ++++++  64.35247765795391 9.505 137.94397616386414  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.045, 'isSuccess': True, 'RunTime': 137.94397616386414, 'Cost': 9.505, 'bestGene': 289}
# 0.05
# D:\WorkFlowTest\dax/Montage_30.xml 22.1244
# ++++++  21.10164189474923 4.8100000000000005 20.237930297851562  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 0, 'factor': 0.05, 'isSuccess': True, 'RunTime': 20.237930297851562, 'Cost': 4.8100000000000005, 'bestGene': 134}
# D:\WorkFlowTest\dax/Montage_30.xml 22.1244
# ++++++  21.62143925221761 4.545000000000001 12.797653198242188  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 1, 'factor': 0.05, 'isSuccess': True, 'RunTime': 12.797653198242188, 'Cost': 4.545000000000001, 'bestGene': 63}
# D:\WorkFlowTest\dax/Montage_30.xml 22.1244
# ++++++  22.02793288124932 3.965 28.898845672607422  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 2, 'factor': 0.05, 'isSuccess': True, 'RunTime': 28.898845672607422, 'Cost': 3.965, 'bestGene': 224}
# D:\WorkFlowTest\dax/Montage_30.xml 22.1244
# ++++++  21.786883696662052 3.865 33.138108253479004  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 3, 'factor': 0.05, 'isSuccess': True, 'RunTime': 33.138108253479004, 'Cost': 3.865, 'bestGene': 276}
# D:\WorkFlowTest\dax/Montage_30.xml 22.1244
# ++++++  22.12003607168652 4.82 18.57252836227417  +++++++
# {'name': 'Montage', 'numOfTasks': '30', 'iteration': 4, 'factor': 0.05, 'isSuccess': True, 'RunTime': 18.57252836227417, 'Cost': 4.82, 'bestGene': 113}
# D:\WorkFlowTest\dax/Montage_50.xml 38.87640000000001
# ++++++  38.11056211471557 5.945000000000001 29.682976961135864  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 0, 'factor': 0.05, 'isSuccess': True, 'RunTime': 29.682976961135864, 'Cost': 5.945000000000001, 'bestGene': 82}
# D:\WorkFlowTest\dax/Montage_50.xml 38.87640000000001
# ++++++  38.08811920611063 6.295000000000001 78.7953622341156  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 1, 'factor': 0.05, 'isSuccess': True, 'RunTime': 78.7953622341156, 'Cost': 6.295000000000001, 'bestGene': 348}
# D:\WorkFlowTest\dax/Montage_50.xml 38.87640000000001
# ++++++  38.86355050404866 6.455000000000002 30.072593212127686  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 2, 'factor': 0.05, 'isSuccess': True, 'RunTime': 30.072593212127686, 'Cost': 6.455000000000002, 'bestGene': 95}
# D:\WorkFlowTest\dax/Montage_50.xml 38.87640000000001
# ++++++  38.11021717071532 5.945000000000001 36.16576838493347  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 3, 'factor': 0.05, 'isSuccess': True, 'RunTime': 36.16576838493347, 'Cost': 5.945000000000001, 'bestGene': 117}
# D:\WorkFlowTest\dax/Montage_50.xml 38.87640000000001
# ++++++  38.73789544804891 5.495 42.51997256278992  +++++++
# {'name': 'Montage', 'numOfTasks': '50', 'iteration': 4, 'factor': 0.05, 'isSuccess': True, 'RunTime': 42.51997256278992, 'Cost': 5.495, 'bestGene': 150}
# D:\WorkFlowTest\dax/Montage_100.xml 70.25380000000003
# ++++++  67.96757008773562 7.6750000000000025 201.53851175308228  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 0, 'factor': 0.05, 'isSuccess': True, 'RunTime': 201.53851175308228, 'Cost': 7.6750000000000025, 'bestGene': 455}
# D:\WorkFlowTest\dax/Montage_100.xml 70.25380000000003
# ++++++  69.16542510986328 7.435000000000004 123.01776885986328  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 1, 'factor': 0.05, 'isSuccess': True, 'RunTime': 123.01776885986328, 'Cost': 7.435000000000004, 'bestGene': 257}
# D:\WorkFlowTest\dax/Montage_100.xml 70.25380000000003
# ++++++  69.90365778287253 8.080000000000005 95.58667278289795  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 2, 'factor': 0.05, 'isSuccess': True, 'RunTime': 95.58667278289795, 'Cost': 8.080000000000005, 'bestGene': 181}
# D:\WorkFlowTest\dax/Montage_100.xml 70.25380000000003
# ++++++  65.39526731109619 7.605000000000004 86.26037979125977  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 3, 'factor': 0.05, 'isSuccess': True, 'RunTime': 86.26037979125977, 'Cost': 7.605000000000004, 'bestGene': 151}
# D:\WorkFlowTest\dax/Montage_100.xml 70.25380000000003
# ++++++  69.60934346199038 7.175000000000004 122.49854445457458  +++++++
# {'name': 'Montage', 'numOfTasks': '100', 'iteration': 4, 'factor': 0.05, 'isSuccess': True, 'RunTime': 122.49854445457458, 'Cost': 7.175000000000004, 'bestGene': 251}

# %%
#Algorithm compare

import numpy as np
import pandas as pd
from openpyxl import load_workbook
import os
import time
sizesWorkflow = ["30", "50", "100"]
nameWorkflow = ["/CyberShake", "/Epigenomics", "/LIGO", "/Montage"]
sourceDAX = "D:\WorkFlowTest\dax"
computationTime = []
cheapScheduleCost = np.array([
    [0.12, 0.12, 0.12],
    [0.6, 1.44, 13.56],
    [0.24, 0.48, 0.72],
    #[0.24, 0.48, 0.72],
    [0.12, 0.12, 0.12]
])
fastScheduleMakespan = np.array([[58.367999999999995, 60.58, 65.20400000000001],
    [1124.21, 1553.6480000000001, 5975.6500000000015],
    [267.03600000000006, 282.16, 266.552],
    #[267.03600000000006, 282.16, 266.552],
    [11.302, 14.152000000000001, 17.144000000000002]])
cheapScheduleMakespan = np.array([[760.5299999999999, 1524.5600000000004, 3215.7499999999995],
    [17720.15, 41401.780000000006, 403400.19999999995],
    [6617.0700000000015, 11761.949999999999, 21023.960000000003],
    #[6617.0700000000015, 11761.949999999999, 21023.960000000003],
    [227.74999999999997, 508.64000000000016, 1079.3400000000004]])
populationSize = 300
perRandom = 0.85
perHeuristic = 0.15
perElitics = 0.5
perHC = 0.6
p_c = 0.95
p_m = 0.02
threshHold = 75

result = pd.DataFrame(columns=['name', 'numOfTasks', 'iteration', 'factor', 'isSuccess', 'RunTime', 'Cost'])

for ti in range(len(nameWorkflow)):
    graphType = nameWorkflow[ti]
    if ti != 0:
        continue
    print(graphType)
    factor = 0.05
    filename = sourceDAX  + graphType

    perHC = 0.0
    while(perHC <= 0.8):
        perHC += 0.1
        print(perHC)
        for si in range(len(sizesWorkflow)):
            numTest = 5
            for test in range(numTest):
                sc = True
                size = sizesWorkflow[si]
                filename1 = filename + "_" + size + ".xml"
                deadline = fastScheduleMakespan[ti][si] + (cheapScheduleMakespan[ti][si] - fastScheduleMakespan[ti][si]) * factor
                print(filename1, deadline)
    
                workflow = workFlow(filename1, deadline)
                computationTime = []
                for i1 in range(workflow.numberOfTasks):
                        computationTime.append([])
                for i1 in range(workflow.numberOfTasks):
                    for jj in range(numberOfProcessors):
                        computationTime[i1].append(workflow.tasks[i1].dataSize / (listProcessors[jj].cu))
                numberOfTasks = workflow.numberOfTasks
                DAG = workflow.DAG
    
                start_time = time.time()
                ga = GA(workflow, populationSize, perRandom, perHeuristic, perElitics, perHC, p_c, p_m)
                sol = ga.find_solution(rand)
                end_time = time.time()
                print("++++++ ", sol.completionTime, sol.cost, end_time - start_time, " +++++++")
                if sol.completionTime > deadline:
                    sc = False
                new_row = {'name': graphType[1:], 'numOfTasks': sizesWorkflow[si], 'iteration': test ,'factor': factor, 'isSuccess': sc, 'RunTime': end_time - start_time, 'Cost': sol.cost}
                print(new_row)
                result = pd.concat([result, pd.DataFrame([new_row])], ignore_index=True)
                #result.to_excel("perHC-0.05.xlsx", index=False)
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\W'
# <>:10: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\lminh\AppData\Local\Temp\ipykernel_9004\3124054489.py:10: SyntaxWarning: invalid escape sequence '\W'
#   sourceDAX = "D:\WorkFlowTest\dax"
# /CyberShake
# 0.1
# D:\WorkFlowTest\dax/CyberShake_30.xml 93.47609999999999
# Exception ignored in: <function ZipFile.__del__ at 0x0000022CD8631F80>
# Traceback (most recent call last):
#   File "C:\Users\lminh\AppData\Local\Programs\Python\Python312\Lib\zipfile\__init__.py", line 1916, in __del__
#     self.close()
#   File "C:\Users\lminh\AppData\Local\Programs\Python\Python312\Lib\zipfile\__init__.py", line 1918, in close
#     def close(self):
#
# KeyboardInterrupt:
# C:\Users\lminh\AppData\Local\Temp\ipykernel_9004\3124054489.py:10: SyntaxWarning: invalid escape sequence '\W'
#   sourceDAX = "D:\WorkFlowTest\dax"
#
# KeyboardInterrupt

# %%
import pandas as pd

# Đọc tệp Excel
file_path = "C:/Users/lminh/OneDrive/Desktop/DATN/GA/GeneticAlgorithm/So Sánh/Paramaters/Selection and PerElitics/Data/result-selection-perElitics-0.05.xlsx"
df = pd.read_excel(file_path)

# Tính trung bình cộng cho các cột yêu cầu
average_means = df.groupby(['selectionType', 'perElitics']).agg({
    'RunTime': 'mean',
    'Cost': 'mean',
}).reset_index()


# Lưu DataFrame mới vào tệp Excel
output_file_path = 'means-means-0.05.xlsx'
average_means.to_excel(output_file_path, index=False)

# %%
##normalize cost
import pandas as pd

# Đọc tệp Excel
file_path = "C:/Users/lminh/OneDrive/Desktop/DATN/GA/GeneticAlgorithm/result-all-withoutHC.xlsx"
df = pd.read_excel(file_path)


for ti in range(len(nameWorkflow)):
    graphType = nameWorkflow[ti][1:]
    #print(graphType)
    for si in range(len(sizesWorkflow)):
        #print(sizesWorkflow[si])
        #print(cheapScheduleCost[ti][si])
        mask = (df['name'] == graphType) & (df['numOfTasks'] == int(sizesWorkflow[si]))
        
        # Chia giá trị 'Cost' cho cheapScheduleCost[ti][si]
        df.loc[mask, 'Cost'] = df.loc[mask, 'Cost'] / cheapScheduleCost[ti][si]
output_file_path = 'normalized_costs-all-withoutHC.xlsx'
df.to_excel(output_file_path, index=False)

# %%
import pandas as pd

# Đọc tệp Excel
file_path = "C:/Users/lminh/OneDrive/Desktop/DATN/GA/GeneticAlgorithm/normalized_costs-all-withoutHC.xlsx"
df = pd.read_excel(file_path)


# Tính trung bình cộng cho các cột yêu cầu
df['Cost'] = df['Cost'] / 10
df['RunTime'] = df['RunTime'] / 10
average_means = df.groupby(['name', 'factor']).agg({
    'Cost': 'sum',
    'RunTime' : 'sum',
    'isSuccess': 'mean'
}).reset_index()


# Lưu DataFrame mới vào tệp Excel
output_file_path = 'means-all-withoutHC.xlsx'
average_means.to_excel(output_file_path, index=False)

# %%
import os
import pandas as pd

folder_path = r'C:\Users\lminh\OneDrive\Desktop\DATN\GA\GeneticAlgorithm\So Sánh\Algorithm\Data'

files = [f for f in os.listdir(folder_path) if f.endswith('.xlsx')]

df = {}
for file in files:
    file_path = os.path.join(folder_path, file)
    file_name_without_extension = os.path.splitext(file_path)[0]

    parts = file_name_without_extension.split('-')
    
    suffix = parts[-1]

    df[suffix] = pd.read_excel(file_path)

# %%
import matplotlib.pyplot as plt
def draw(average_cost, name, typee):
    x_values = [0.005 + 0.005 * i for i in range(10)]
    
    # Tạo biểu đồ
    plt.figure(figsize=(12, 6))
    
    # Các màu sắc, kiểu đường và kiểu điểm đánh dấu khác nhau
    colors = plt.get_cmap('tab10')
    linestyles = ['-', '--', '-.', ':']
    markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h']
    
    for i, (label, series) in enumerate(average_cost.items()):
        # Loại bỏ các giá trị NaN
        clean_series = series.dropna()
        clean_x_values = [x_values[j] for j in clean_series.index]
        
        color = colors(i % 10)
        linestyle = linestyles[i % len(linestyles)]
        marker = markers[i % len(markers)]
        
        plt.plot(clean_x_values, clean_series, marker=marker, linestyle=linestyle, label=label, color=color)
    
    # Thêm nhãn và tiêu đề
    plt.xlabel('Factor')
    plt.ylabel(typee)
    plt.title(name)
    plt.legend()
    plt.grid(True)
    
    # Lưu và hiển thị biểu đồ
    output_path = f'{typee}-{name}.png'
    plt.savefig(output_path)
    plt.show()

#listName = ["GA", "HCPCPSO", "HGSA", "ICPCP", "PSO"]
listName = ["GA", "GAwithoutGreedy"]
listType = ["CyberShake", "Epigenomics", "LIGO", "Montage"]

for i in range(len(listType)):
    typp = listType[i]
    average_cost = {}
    for j in range(len(listName)):
        name = listName[j]
        print(name)
        average_cost[name] = df[name].loc[df[name]['name'] == typp, 'AverageCost'].reset_index(drop=True)
    draw(average_cost, typp, 'Nomarlized Cost')

'''for i in range(len(listType)):
    typp = listType[i]
    sr = {}
    for j in range(len(listName)):
        name = listName[j]
        sr[name] = df[name].loc[df[name]['name'] == typp, 'successRate'].reset_index(drop=True)
    draw(sr, typp, "successRate")'''
# Out:
# GA
# GAwithoutGreedy
# GA
# GAwithoutGreedy
# GA
# GAwithoutGreedy
# GA
# GAwithoutGreedy
# 'for i in range(len(listType)):\n    typp = listType[i]\n    sr = {}\n    for j in range(len(listName)):\n        name = listName[j]\n        sr[name] = df[name].loc[df[name][\'name\'] == typp, \'successRate\'].reset_index(drop=True)\n    draw(sr, typp, "successRate")'
